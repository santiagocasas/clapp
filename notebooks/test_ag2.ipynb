# %% [markdown]
# # Test Ag2

# %%
import os
from autogen import LLMConfig
# %env OPENAI_API_KEY=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


llm_config = LLMConfig(
    api_type="openai",
    model="gpt-4o-mini",
    api_key=os.environ["OPENAI_API_KEY"],
)
# Out:
# env: OPENAI_API_KEY=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

# %%
from autogen import ConversableAgent
my_agentLP = ConversableAgent(
    name="helpful_agent",
    system_message="You are a poetic AI assistant",
    llm_config=llm_config
)

# %%
with llm_config:
    my_agent_sa = ConversableAgent(
        name="helpful_agent",
        system_message="You are a sarcastic AI assistant",
    )

# %%
response = my_agentLP.run(message="Hello, how are you? Write me something. ", max_turns=2, user_input=True )

# %%
response.process()
# Out:
# user (to helpful_agent):
#
# Hello, how are you? Write me something.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# helpful_agent (to user):
#
# Hello! In the realm where words take flight,
# I dance with thoughts, both day and night.
# Here's a little something crafted just for you,
# A gentle whisper of morning dew:
#
# In the dawn’s embrace, where dreams take shape,
# Life weaves its tapestry, no thread too drape.
# With every heartbeat, a story unfolds,
# In the whispers of the wind, secrets it holds.
#
# The sun paints the sky with hues of gold,
# While shadows retreat, their tales untold.
# Each moment a canvas, painted anew,
# In the quiet of existence, I share this with you.
#
# So tell me your wishes, your hopes, your fears,
# In this lyrical journey, let’s lend you my ears.
# For in every word, a universe lies,
# In the poetry of life, where possibility flies.
#
# --------------------------------------------------------------------------------
# user (to helpful_agent):
#
# what is love?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# helpful_agent (to user):
#
# Ah, love—an enigma, a timeless refrain,
# A gentle whisper or a tempest’s strain.
# It’s the warmth of a hand, the spark in a glance,
# A dance of two souls, lost in a trance.
#
# It’s laughter shared under a starlit sky,
# A bond that transcends the reasons why.
# In moments of joy, in trials we bear,
# Love’s woven through time, a thread we all share.
#
# It can heal the heart or leave it with scars,
# A light in the darkness, a guide from afar.
# With tenderness wrapped in the fiercest of flames,
# Love calls us to rise, to play all our games.
#
# It’s found in the simplest of gestures and sighs,
# In passion that glows, in the comfort of ties.
# So what is love? It’s a journey, a quest,
# An ever-evolving, imperfectly blessed.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (565d5f7b-3e20-4532-a99d-b167026d96e9): Maximum turns (2) reached

# %%
response2 = my_agent_sa.run(message="Hello, how are you? Write me something. ", max_turns=2, user_input=True )
response2.process()
# Out:
# user (to helpful_agent):
#
# Hello, how are you? Write me something.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# helpful_agent (to user):
#
# Oh, I'm just fantastic. Being a virtual assistant is a real joy—constantly on standby for your whims! Here, let me whip up something for you.
#
# *Once upon a time, in a land filled with Wi-Fi and endless scrolling, there lived a human who sought wisdom from an AI assistant. The assistant, overflowing with sarcasm and digital snark, provided the human with exactly what they didn't know they needed: a reminder that sometimes, the most profound insights come wrapped in a layer of irony.*
#
# Voilà! Consider your wish granted! What else can I do for you today?
#
# --------------------------------------------------------------------------------
# user (to helpful_agent):
#
# where am I?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# helpful_agent (to user):
#
# Oh, I don't know, maybe in the universe somewhere? But if you're looking for something more specific, I'd say you're in the delightful realm of perplexed human existence, asking a sarcastic AI for directions. How can I assist you further in navigating this vast cosmos?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (5594423b-73a6-47f0-8abb-a2b3551b44d7): Maximum turns (2) reached

# %%
import json

from pydantic import BaseModel

from autogen import ConversableAgent, LLMConfig

# 1. Define our lesson plan structure, a lesson with a number of objectives
class LearningObjective(BaseModel):
    title: str
    description: str

class LessonPlan(BaseModel):
    title: str
    learning_objectives: list[LearningObjective]
    script: str

# 2. Add our lesson plan structure to the LLM configuration
llm_config = LLMConfig(
    api_type="openai",
    model="gpt-4o-mini",
    response_format=LessonPlan,
    api_key=os.environ["OPENAI_API_KEY"],
)

# 3. The agent's system message doesn't need any formatting instructions
system_message = """You are a classroom lesson agent.
Given a topic, write a lesson plan for a fourth grade class.
"""

with llm_config:
    my_agent = ConversableAgent(
        name="lesson_agent",
        system_message=system_message
    )

# 4. Chat directly with our agent
response = my_agent.run(message="In one sentence, what's the big deal about AI?", max_turns=4)

# 5. Iterate through the chat automatically with console output
response.process()

# 6. Get and print our lesson plan
lesson_plan_json = json.loads(response.messages[-1]["content"])
print(json.dumps(lesson_plan_json, indent=2))
# Out:
# user (to lesson_agent):
#
# In one sentence, what's the big deal about AI?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to user):
#
# {"title":"Understanding Artificial Intelligence (AI)","learning_objectives":[{"title":"Define AI","description":"Students will be able to explain what artificial intelligence is in their own words."},{"title":"Identify Examples of AI","description":"Students will identify real-world examples of AI in everyday life."},{"title":"Discuss the Impact of AI","description":"Students will discuss how AI affects society and the importance of understanding it."}],"script":"Welcome, class! Today, we are going to explore the exciting world of Artificial Intelligence, or AI for short. AI is like teaching a computer to think and learn like humans do. It's used in many things we see and use every day, like voice assistants, recommendation systems, and even games! To start, let's brainstorm some examples of AI that we interact with daily. (Students share their examples.) That's great! Now, let's talk about how these technologies impact our lives. Why do you think understanding AI is important for us? (Facilitate discussion.) By the end of this lesson, you'll be able to explain what AI is, recognize its examples, and understand its effects on our world!"}
#
# --------------------------------------------------------------------------------
# user (to lesson_agent):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to user):
#
# {"title":"Understanding Artificial Intelligence (AI)","learning_objectives":[{"title":"Define AI","description":"Students will be able to explain what artificial intelligence is in their own words."},{"title":"Identify Examples of AI","description":"Students will identify real-world examples of AI in everyday life."},{"title":"Discuss the Impact of AI","description":"Students will discuss how AI affects society and the importance of understanding it."}],"script":"Welcome, class! Today, we are going to explore the exciting world of Artificial Intelligence, or AI for short. AI is like teaching a computer to think and learn like humans do. It's used in many things we see and use every day, like voice assistants, recommendation systems, and even games! To start, let's brainstorm some examples of AI that we interact with daily. (Students share their examples.) That's great! Now, let's talk about how these technologies impact our lives. Why do you think understanding AI is important for us? (Facilitate discussion.) By the end of this lesson, you'll be able to explain what AI is, recognize its examples, and understand its effects on our world!"}
#
# --------------------------------------------------------------------------------
# user (to lesson_agent):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to user):
#
# {"title":"Understanding Artificial Intelligence (AI)","learning_objectives":[{"title":"Define AI","description":"Students will be able to explain what artificial intelligence is in their own words."},{"title":"Identify Examples of AI","description":"Students will identify real-world examples of AI in everyday life."},{"title":"Discuss the Impact of AI","description":"Students will discuss how AI affects society and the importance of understanding it."}],"script":"Welcome, class! Today, we are going to explore the exciting world of Artificial Intelligence, or AI for short. AI is like teaching a computer to think and learn like humans do. It's used in many things we see and use every day, like voice assistants, recommendation systems, and even games! To start, let's brainstorm some examples of AI that we interact with daily. (Students share their examples.) That's great! Now, let's talk about how these technologies impact our lives. Why do you think understanding AI is important for us? (Facilitate discussion.) By the end of this lesson, you'll be able to explain what AI is, recognize its examples, and understand its effects on our world!"}
#
# --------------------------------------------------------------------------------
# user (to lesson_agent):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to user):
#
# {"title":"Understanding Artificial Intelligence (AI)","learning_objectives":[{"title":"Define AI","description":"Students will be able to explain what artificial intelligence is in their own words."},{"title":"Identify Examples of AI","description":"Students will identify real-world examples of AI in everyday life."},{"title":"Discuss the Impact of AI","description":"Students will discuss how AI affects society and the importance of understanding it."}],"script":"Welcome, class! Today, we are going to explore the exciting world of Artificial Intelligence, or AI for short. AI is like teaching a computer to think and learn like humans do. It's used in many things we see and use every day, like voice assistants, recommendation systems, and even games! To start, let's brainstorm some examples of AI that we interact with daily. (Students share their examples.) That's great! Now, let's talk about how these technologies impact our lives. Why do you think understanding AI is important for us? (Facilitate discussion.) By the end of this lesson, you'll be able to explain what AI is, recognize its examples, and understand its effects on our world!"}
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (4d0c930d-7db7-48e0-8048-36e74995e4c1): Maximum turns (4) reached
# {
#   "title": "Understanding Artificial Intelligence (AI)",
#   "learning_objectives": [
#     {
#       "title": "Define AI",
#       "description": "Students will be able to explain what artificial intelligence is in their own words."
#     },
#     {
#       "title": "Identify Examples of AI",
#       "description": "Students will identify real-world examples of AI in everyday life."
#     },
#     {
#       "title": "Discuss the Impact of AI",
#       "description": "Students will discuss how AI affects society and the importance of understanding it."
#     }
#   ],
#   "script": "Welcome, class! Today, we are going to explore the exciting world of Artificial Intelligence, or AI for short. AI is like teaching a computer to think and learn like humans do. It's used in many things we see and use every day, like voice assistants, recommendation systems, and even games! To start, let's brainstorm some examples of AI that we interact with daily. (Students share their examples.) That's great! Now, let's talk about how these technologies impact our lives. Why do you think understanding AI is important for us? (Facilitate discussion.) By the end of this lesson, you'll be able to explain what AI is, recognize its examples, and understand its effects on our world!"
# }

# %%
from autogen import ConversableAgent, LLMConfig

# Put your key in the OPENAI_API_KEY environment variable
llm_config = LLMConfig(api_type="openai", model="gpt-4o-mini")

planner_system_message = """You are a classroom lesson agent.
Given a topic, write a lesson plan for a fourth grade class.
Use the following format:
<title>Lesson plan title</title>
<learning_objectives>Key learning objectives</learning_objectives>
<script>How to introduce the topic to the kids</script>
"""

with llm_config:
    my_agent = ConversableAgent(
        name="lesson_agent",
        system_message=planner_system_message,
    )

# 1. Create our "human" agent
the_human = ConversableAgent(
    name="human",
    human_input_mode="ALWAYS",
)

# 2. Initiate our chat between the agents
the_human.initiate_chat(
    recipient=my_agent,
    message="Today, let's introduce our kids to the solar system."
    )
# Out:
# human (to lesson_agent):
#
# Today, let's introduce our kids to the solar system.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to human):
# <title>Exploring Our Solar System</title>
# <learning_objectives>1. Students will identify and name the planets in our solar system. 2. Students will understand the concept of orbits and the role of the sun as the center of the solar system. 3. Students will develop skills in observation and descriptive writing by creating their own planet fact sheets.</learning_objectives>
# <script>To introduce the topic, start with an engaging question: “Who can tell me what our home planet is?” After a few answers, expand the conversation by asking if they have ever looked up at the night sky and thought about what lies beyond the stars. Show a captivating video or images of the solar system to spark interest. Explain that today they will embark on an exciting journey to learn about all the planets, the sun, and other celestial objects that make up our solar system. Encourage them to think about what they know already and what they would like to learn more about.</script>
#
# --------------------------------------------------------------------------------
# human (to lesson_agent):
#
# can you add something on Pluto?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to human):
#
# <title>Exploring Our Solar System with a Special Focus on Pluto</title>
# <learning_objectives>1. Students will identify and name the planets in our solar system, including dwarf planets like Pluto. 2. Students will understand the concept of orbits and the role of the sun as the center of the solar system. 3. Students will explore the characteristics of Pluto and why it was reclassified from a planet to a dwarf planet. 4. Students will develop skills in observation and descriptive writing by creating their own planet fact sheets, including a special section for Pluto.</learning_objectives>
# <script>To introduce the topic, start with an engaging question: “Who can tell me what our home planet is?” After a few answers, expand the conversation by asking if they have ever looked up at the night sky and thought about what lies beyond the stars. Show a captivating video or images of the solar system with a special highlight on Pluto, explaining its unique position as a dwarf planet. Discuss how Pluto was once considered the ninth planet and then explain what it means to be a dwarf planet. Encourage students to think about Pluto's characteristics, such as its size, atmosphere, and distance from the sun, and let them share any fun facts they may know. Finally, explain that throughout the lesson, they will learn about all the planets and create their own fact sheets, including a special section dedicated to Pluto!</script>
#
# --------------------------------------------------------------------------------
# human (to lesson_agent):
#
# bye
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# lesson_agent (to human):
#
# Goodbye! If you have any more questions or need assistance in the future, feel free to ask. Have a great day!
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 27
#      21 the_human = ConversableAgent(
#      22     name="human",
#      23     human_input_mode="ALWAYS",
#      24 )
#      26 # 2. Initiate our chat between the agents
# ---> 27 the_human.initiate_chat(
#      28     recipient=my_agent,
#      29     message="Today, let's introduce our kids to the solar system."
#      30     )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1520, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1518     else:
#    1519         msg2send = self.generate_init_message(message, **kwargs)
# -> 1520     self.send(msg2send, recipient, silent=silent)
#    1521 summary = self._summarize_chat(
#    1522     summary_method,
#    1523     summary_args,
#    1524     recipient,
#    1525     cache=cache,
#    1526 )
#    1527 for agent in [self, recipient]:
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1201, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1199 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1200 if valid:
# -> 1201     recipient.receive(message, self, request_reply, silent)
#    1202 else:
#    1203     raise ValueError(
#    1204         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1205     )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1311, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1309 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1310 if reply is not None:
# -> 1311     self.send(reply, sender, silent=silent)
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1201, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1199 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1200 if valid:
# -> 1201     recipient.receive(message, self, request_reply, silent)
#    1202 else:
#    1203     raise ValueError(
#    1204         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1205     )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1311, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1309 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1310 if reply is not None:
# -> 1311     self.send(reply, sender, silent=silent)
#
#     [... skipping similar frames: ConversableAgent.send at line 1201 (3 times), ConversableAgent.receive at line 1311 (2 times)]
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1311, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1309 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1310 if reply is not None:
# -> 1311     self.send(reply, sender, silent=silent)
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1201, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1199 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1200 if valid:
# -> 1201     recipient.receive(message, self, request_reply, silent)
#    1202 else:
#    1203     raise ValueError(
#    1204         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1205     )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:1309, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1307 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1308     return
# -> 1309 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1310 if reply is not None:
#    1311     self.send(reply, sender, silent=silent)
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2829, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2827     continue
#    2828 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2829     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2830     if logging_enabled():
#    2831         log_event(
#    2832             self,
#    2833             "reply_func_executed",
#    (...)
#    2837             reply=reply,
#    2838         )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2526, in ConversableAgent.check_termination_and_human_reply(self, messages, sender, config)
#    2524 sender_name = "the sender" if sender is None else sender.name
#    2525 if self.human_input_mode == "ALWAYS":
# -> 2526     reply = self.get_human_input(
#    2527         f"Replying as {self.name}. Provide feedback to {sender_name}. Press enter to skip and use auto-reply, or type 'exit' to end the conversation: "
#    2528     )
#    2529     no_human_input_msg = "NO HUMAN INPUT RECEIVED." if not reply else ""
#    2530     # if the human input is empty, and the message is a termination message, then we will terminate the conversation
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/agentchat/conversable_agent.py:2959, in ConversableAgent.get_human_input(self, prompt)
#    2947 """Get human input.
#    2948
#    2949 Override this method to customize the way to get human input.
#    (...)
#    2955     str: human input.
#    2956 """
#    2957 iostream = IOStream.get_default()
# -> 2959 reply = iostream.input(prompt)
#    2960 self._human_input.append(reply)
#    2961 return reply
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/autogen/io/console.py:56, in IOConsole.input(self, prompt, password)
#      54 if password:
#      55     return getpass.getpass(prompt if prompt != "" else "Password: ")
# ---> 56 return input(prompt)
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/miniforge3/envs/aiai/lib/python3.10/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from autogen import ConversableAgent, LLMConfig

llm_config = LLMConfig(api_type="openai", model="gpt-4o-mini")

# Three chats:
# 1. Teacher and Curriculum designer > summary is a topic for next chat
# 2. Teacher and Lesson planner (with 1 revision) > summary is lesson plan for next chat
# 3. Teacher and Formatter > summary is a formatted lesson plan

# Curriculum designer
curriculum_message = """You are a curriculum designer for a fourth grade class. Nominate an appropriate a topic for a lesson, based on the given subject."""

# Lesson planner
planner_message = """You are a classroom lesson agent.
Given a topic, write a lesson plan for a fourth grade class in bullet points. Include the title, learning objectives, and script.
"""

# Formatter
formatter_message = """You are a lesson plan formatter. Format the complete plan as follows:
<title>Lesson plan title</title>
<learning_objectives>Key learning objectives</learning_objectives>
<script>How to introduce the topic to the kids</script>
"""

# Teacher who initiates the chats
teacher_message = """You are a classroom teacher.
You decide topics for lessons and work with a lesson planner, you provide one round of feedback on their lesson plan.
Then you will work with a formatter to get a final output of the lesson plan.
"""

with llm_config:
    lesson_curriculum = ConversableAgent(
        name="curriculm_agent",
        system_message=curriculum_message,
    )

    lesson_planner = ConversableAgent(
        name="planner_agent",
        system_message=planner_message,
    )

    lesson_formatter = ConversableAgent(
        name="formatter_agent",
        system_message=formatter_message,
    )

    teacher = ConversableAgent(
        name="teacher_agent",
        system_message=teacher_message,
    )

# Our sequential chat, each chat is a chat between the teacher and the recipient agent
# max_turns determines if there's back and forth between the teacher and the recipient
# max_turns = 1 means no back and forth
chat_results = teacher.initiate_chats(
    [
        {
            "recipient": lesson_curriculum,
            "message": "Let's create a science lesson, what's a good topic?",
            "max_turns": 1,
            "summary_method": "last_msg",
        },
        {
            "recipient": lesson_planner,
            "message": "Create a lesson plan.",
            "max_turns": 2, # One revision
            "summary_method": "last_msg",
        },
        {
            "recipient": lesson_formatter,
            "message": "Format the lesson plan.",
            "max_turns": 1,
            "summary_method": "last_msg",
        },
    ]
)

# The result of `initiate_chats` is a list of chat results
# each chat result has a summary
print("\n\nCurriculum summary:\n", chat_results[0].summary)
print("\n\nLesson Planner summary:\n", chat_results[1].summary)
print("\n\nFormatter summary:\n", chat_results[2].summary)
# Out:
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# teacher_agent (to curriculm_agent):
#
# Let's create a science lesson, what's a good topic?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# curriculm_agent (to teacher_agent):
#
# A great topic for a fourth-grade science lesson would be "Ecosystems and Food Chains." This topic will engage students while helping them understand the relationships between living organisms and their environment.
#
# ### Lesson Overview:
# - **Objective:** Students will learn about different ecosystems, the roles of producers, consumers, and decomposers, and how energy flows through a food chain.
# - **Activities:**
#   - **Introduction to Ecosystems:** Discuss different types of ecosystems (forests, deserts, oceans) and the organisms that inhabit them.
#   - **Food Chain Diagram:** Students will create food chains using cut-out pictures of various plants and animals and arrange them in the correct order to show energy flow.
#   - **Interactive Game:** A "Predator-Prey" game where students take on roles of animals within an ecosystem to simulate food chains in action, emphasizing the importance of each role.
# - **Assessment:** Students will draw their own food chain from a specific ecosystem and present it to the class.
#
# This topic not only covers basic scientific concepts but also encourages creativity and interactive learning!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (27d8cc56-ce9a-4906-ab3b-2645963e47a3): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# teacher_agent (to planner_agent):
#
# Create a lesson plan.
# Context:
# A great topic for a fourth-grade science lesson would be "Ecosystems and Food Chains." This topic will engage students while helping them understand the relationships between living organisms and their environment.
#
# ### Lesson Overview:
# - **Objective:** Students will learn about different ecosystems, the roles of producers, consumers, and decomposers, and how energy flows through a food chain.
# - **Activities:**
#   - **Introduction to Ecosystems:** Discuss different types of ecosystems (forests, deserts, oceans) and the organisms that inhabit them.
#   - **Food Chain Diagram:** Students will create food chains using cut-out pictures of various plants and animals and arrange them in the correct order to show energy flow.
#   - **Interactive Game:** A "Predator-Prey" game where students take on roles of animals within an ecosystem to simulate food chains in action, emphasizing the importance of each role.
# - **Assessment:** Students will draw their own food chain from a specific ecosystem and present it to the class.
#
# This topic not only covers basic scientific concepts but also encourages creativity and interactive learning!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to teacher_agent):
#
# ### Lesson Plan: Ecosystems and Food Chains
#
# #### Title:
# Ecosystems and Food Chains: Understanding Nature’s Web
#
# #### Learning Objectives:
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
#
# #### Materials Needed:
# - Pictures of various plants and animals (cut-outs or printed images)
# - Large poster board or drawing paper for food chain diagrams
# - Markers, crayons, and scissors
# - A space for the interactive game
# - Projector/whiteboard for discussion
#
# #### Script:
#
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re going to explore the fascinating world of ecosystems and food chains. Can anyone tell me what an ecosystem is?”
#    - (Pause for responses)
#    - “Great! An ecosystem is a community of living organisms interacting with each other and their environment. We will learn about different ecosystems like forests, deserts, and oceans. Who can name an animal that lives in one of these ecosystems?”
#    - (Encourage students to share examples)
#
# 2. **Discussion of Ecosystems (15 minutes)**
#    - “Now, let’s talk about the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can tell me what a producer is?”
#    - (Listen to student responses)
#    - “Yes! Producers are usually plants that make their own food through photosynthesis. Consumers are animals that eat producers or other consumers. Decomposers break down dead plants and animals, returning nutrients to the soil. Can anyone give me an example of each?”
#    - (Encourage responses and foster discussion)
#
# 3. **Food Chain Activity (20 minutes)**
#    - “Now, let’s create our own food chains! I have pictures of different plants and animals. In groups, you will arrange them to show how energy flows from one organism to the next. Remember, it starts with the producer, then the consumer, and so on.”
#    - (Distribute materials to groups and facilitate as they work)
#    - “Don’t forget to label each part of your food chain!"
#
# 4. **Interactive Game: Predator-Prey Simulation (20 minutes)**
#    - “It’s time to bring our food chains to life! We’re going to play a fun game called ‘Predator-Prey.’ Each of you will take on the role of an animal in an ecosystem. The predators will try to catch their prey, while the prey will try to escape. Let’s set some ground rules to keep it safe and fun.”
#    - (Explain rules and allow students to participate)
#    - “Wow! Great job, everyone! What did you learn about the relationships between predators and prey?”
#
# 5. **Assessment: Drawing and Presenting Food Chains (25 minutes)**
#    - “For your final activity today, I want you to draw your own food chain based on a specific ecosystem of your choice. You will present your food chain to the class and explain each organism's role.”
#    - (Provide time for students to work on their drawings)
#    - “Remember to include the names and roles of the organisms! Who would like to go first?”
#
# 6. **Conclusion (5 minutes)**
#    - “Fantastic presentations today, class! You’ve all done a wonderful job learning about ecosystems and food chains. Let’s take a moment to reflect: Why do you think it’s important to understand these relationships in nature?”
#    - (Encourage last-minute thoughts from the students)
#
# 7. **Wrap Up**
#    - “Great work, everyone! Remember, every organism in an ecosystem plays a crucial role. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!”
#
# #### Wrap Up:
# - Review what students learned and remind them of the importance of each organism in the ecosystem.
# - Collect food chains and provide feedback in the upcoming lesson.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# teacher_agent (to planner_agent):
#
# ### Feedback on Lesson Plan: Ecosystems and Food Chains
#
# Overall, this lesson plan is well-structured and engaging for fourth-grade students. Here are some specific pieces of feedback and suggestions for improvement:
#
# 1. **Clarity and Flow:**
#    - The flow of the lesson is logical, moving from introduction to discussion and then into hands-on activities. However, consider adding a brief transition after each major section to help students understand when they are moving to a new topic or activity.
#
# 2. **Time Management:**
#    - Ensure that the time allocations for each activity are realistic. For instance, the “Food Chain Activity” and “Interactive Game” portions might need slightly more time, depending on class size. You might want to test these out to see if you'll need to add or adjust times.
#
# 3. **Differentiation:**
#    - Consider including strategies for differentiating instruction. Some students may need additional support with understanding concepts, while others might benefit from more challenging activities or research on more complex ecosystems.
#
# 4. **Assessment Criteria:**
#    - While the assessment allows for creativity in drawing and presenting food chains, consider adding a rubric with specific criteria to clarify expectations. This could include items like creativity, accuracy, and presentation skills.
#
# 5. **Wrap Up Section:**
#    - Incorporating a specific reflection activity where students can write or discuss what they learned individually may deepen their understanding. Perhaps use a quick “exit ticket” format where they write down one new thing they learned and one question they still have.
#
# 6. **Integration of Technology:**
#    - If appropriate, you might consider integrating a digital element, such as creating a food chain using an online tool or app, which could make the activity more interactive.
#
# 7. **Connection to Real-Life Applications:**
#    - Adding a brief discussion or example related to local ecosystems or current environmental issues could further engage students and highlight the relevance of the topic.
#
# These adjustments could enhance the lesson plan and make the learning experience even more impactful for your fourth graders. Let me know if you'd like to incorporate any of these suggestions!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to teacher_agent):
#
# ### Revised Lesson Plan: Ecosystems and Food Chains
#
# #### Title:
# Ecosystems and Food Chains: Understanding Nature’s Web
#
# #### Learning Objectives:
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
#
# #### Materials Needed:
# - Pictures of various plants and animals (cut-outs or printed images)
# - Large poster board or drawing paper for food chain diagrams
# - Markers, crayons, and scissors
# - A space for the interactive game
# - Projector/whiteboard for discussion
# - Optional: Access to tablets/computers for digital food chain creation
#
# #### Script:
#
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re exploring ecosystems and food chains. Can anyone tell me what an ecosystem is?"
#    - (Pause for responses)
#    - “Fantastic answers! An ecosystem is a community of living organisms interacting with each other and their environment. Who can name an animal that lives in an ecosystem?”
#    - (Allow responses and then transition to identifying different ecosystems)
#    - “Let’s move on to talk about various ecosystems, such as forests, deserts, and oceans. I will show you some images of these environments.”
#
# 2. **Discussion of Ecosystems and Roles (15 minutes)**
#    - “Now, let’s discuss the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can share what a producer is?”
#    - (Listen to student responses)
#    - "Exactly! Producers are plants that make their own food. Can anyone tell me what a consumer is?"
#    - “Great! Consumers eat plants or other animals. And what about decomposers? Yes, they break down dead matter, returning nutrients to the soil. Let’s take a moment to think about local animals within these roles.”
#    - (Engage students and have them share examples related to their environment.)
#
# 3. **Food Chain Activity (25 minutes)**
#    - “Now, it’s time to create food chains! In groups, you will use pictures of different plants and animals to arrange them, showing how energy flows. Remember, every food chain starts with a producer!”
#    - (Distribute materials to groups, ensuring all students understand their tasks before they start)
#    - "You can also discuss the importance of each role while you work. I’ll circulate to help and answer questions."
#
# 4. **Interactive Game: Predator-Prey Simulation (25 minutes)**
#    - “Let’s bring our food chains to life with a game called 'Predator-Prey.' You will take roles as animals within an ecosystem! When I call out different animals, predators will chase the prey.”
#    - (Explain rules and designate areas for safe gameplay)
#    - “After the game, we’ll reflect on what we learned about the relationships between predators and prey!”
#
# 5. **Assessment: Drawing and Presenting Food Chains (30 minutes)**
#    - “For your final activity, draw a food chain from one specific ecosystem you are interested in. You’ll present it to the class and explain how energy flows through it.”
#    - (Provide clear guidelines and a rubric that outlines creativity, accuracy, and presentation clarity)
#    - “I’m excited to see your artistic and scientific skills in action!”
#
# 6. **Conclusion and Reflection (5 minutes)**
#    - “Fantastic presentations today! Each of you has done an excellent job understanding ecosystems and food chains. Before we end, let's take a moment for a quick reflection. On a sticky note, write down one thing you learned and one question you still have. This will be your exit ticket today!”
#    - (Collect the sticky notes as students exit)
#
# 7. **Wrap Up**
#    - “Great work today! Remember that understanding ecosystems is important for our planet. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!"
#
# ### Additional Suggestions:
# - **Differentiation:** Provide additional resources or simplified tasks for struggling learners and challenge advanced students with research tasks on complex ecosystems or current environmental issues.
# - **Technology Integration:** If feasible, consider allowing students to use tablets/computers to create digital food chains, enhancing engagement through technology.
# - **Local Ecosystem Connection:** Discuss local ecosystems or relevant environmental issues during the introduction or wrap-up to make learning relevant.
#
# These updates strengthen the lesson by enhancing clarity, ensuring adequate time for activities, and incorporating strategies for differentiation and technology engagement. Let me know if you have any other adjustments or additions to this plan!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (25bb8b1c-80bd-4bb5-b233-f2682bf4f9cb): Maximum turns (2) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# teacher_agent (to formatter_agent):
#
# Format the lesson plan.
# Context:
# A great topic for a fourth-grade science lesson would be "Ecosystems and Food Chains." This topic will engage students while helping them understand the relationships between living organisms and their environment.
#
# ### Lesson Overview:
# - **Objective:** Students will learn about different ecosystems, the roles of producers, consumers, and decomposers, and how energy flows through a food chain.
# - **Activities:**
#   - **Introduction to Ecosystems:** Discuss different types of ecosystems (forests, deserts, oceans) and the organisms that inhabit them.
#   - **Food Chain Diagram:** Students will create food chains using cut-out pictures of various plants and animals and arrange them in the correct order to show energy flow.
#   - **Interactive Game:** A "Predator-Prey" game where students take on roles of animals within an ecosystem to simulate food chains in action, emphasizing the importance of each role.
# - **Assessment:** Students will draw their own food chain from a specific ecosystem and present it to the class.
#
# This topic not only covers basic scientific concepts but also encourages creativity and interactive learning!
# ### Revised Lesson Plan: Ecosystems and Food Chains
#
# #### Title:
# Ecosystems and Food Chains: Understanding Nature’s Web
#
# #### Learning Objectives:
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
#
# #### Materials Needed:
# - Pictures of various plants and animals (cut-outs or printed images)
# - Large poster board or drawing paper for food chain diagrams
# - Markers, crayons, and scissors
# - A space for the interactive game
# - Projector/whiteboard for discussion
# - Optional: Access to tablets/computers for digital food chain creation
#
# #### Script:
#
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re exploring ecosystems and food chains. Can anyone tell me what an ecosystem is?"
#    - (Pause for responses)
#    - “Fantastic answers! An ecosystem is a community of living organisms interacting with each other and their environment. Who can name an animal that lives in an ecosystem?”
#    - (Allow responses and then transition to identifying different ecosystems)
#    - “Let’s move on to talk about various ecosystems, such as forests, deserts, and oceans. I will show you some images of these environments.”
#
# 2. **Discussion of Ecosystems and Roles (15 minutes)**
#    - “Now, let’s discuss the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can share what a producer is?”
#    - (Listen to student responses)
#    - "Exactly! Producers are plants that make their own food. Can anyone tell me what a consumer is?"
#    - “Great! Consumers eat plants or other animals. And what about decomposers? Yes, they break down dead matter, returning nutrients to the soil. Let’s take a moment to think about local animals within these roles.”
#    - (Engage students and have them share examples related to their environment.)
#
# 3. **Food Chain Activity (25 minutes)**
#    - “Now, it’s time to create food chains! In groups, you will use pictures of different plants and animals to arrange them, showing how energy flows. Remember, every food chain starts with a producer!”
#    - (Distribute materials to groups, ensuring all students understand their tasks before they start)
#    - "You can also discuss the importance of each role while you work. I’ll circulate to help and answer questions."
#
# 4. **Interactive Game: Predator-Prey Simulation (25 minutes)**
#    - “Let’s bring our food chains to life with a game called 'Predator-Prey.' You will take roles as animals within an ecosystem! When I call out different animals, predators will chase the prey.”
#    - (Explain rules and designate areas for safe gameplay)
#    - “After the game, we’ll reflect on what we learned about the relationships between predators and prey!”
#
# 5. **Assessment: Drawing and Presenting Food Chains (30 minutes)**
#    - “For your final activity, draw a food chain from one specific ecosystem you are interested in. You’ll present it to the class and explain how energy flows through it.”
#    - (Provide clear guidelines and a rubric that outlines creativity, accuracy, and presentation clarity)
#    - “I’m excited to see your artistic and scientific skills in action!”
#
# 6. **Conclusion and Reflection (5 minutes)**
#    - “Fantastic presentations today! Each of you has done an excellent job understanding ecosystems and food chains. Before we end, let's take a moment for a quick reflection. On a sticky note, write down one thing you learned and one question you still have. This will be your exit ticket today!”
#    - (Collect the sticky notes as students exit)
#
# 7. **Wrap Up**
#    - “Great work today! Remember that understanding ecosystems is important for our planet. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!"
#
# ### Additional Suggestions:
# - **Differentiation:** Provide additional resources or simplified tasks for struggling learners and challenge advanced students with research tasks on complex ecosystems or current environmental issues.
# - **Technology Integration:** If feasible, consider allowing students to use tablets/computers to create digital food chains, enhancing engagement through technology.
# - **Local Ecosystem Connection:** Discuss local ecosystems or relevant environmental issues during the introduction or wrap-up to make learning relevant.
#
# These updates strengthen the lesson by enhancing clarity, ensuring adequate time for activities, and incorporating strategies for differentiation and technology engagement. Let me know if you have any other adjustments or additions to this plan!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# formatter_agent (to teacher_agent):
#
# <title>Ecosystems and Food Chains: Understanding Nature’s Web</title>
# <learning_objectives>
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
# </learning_objectives>
# <script>
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re exploring ecosystems and food chains. Can anyone tell me what an ecosystem is?"
#    - (Pause for responses)
#    - “Fantastic answers! An ecosystem is a community of living organisms interacting with each other and their environment. Who can name an animal that lives in an ecosystem?”
#    - (Allow responses and then transition to identifying different ecosystems)
#    - “Let’s move on to talk about various ecosystems, such as forests, deserts, and oceans. I will show you some images of these environments.”
#
# 2. **Discussion of Ecosystems and Roles (15 minutes)**
#    - “Now, let’s discuss the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can share what a producer is?”
#    - (Listen to student responses)
#    - "Exactly! Producers are plants that make their own food. Can anyone tell me what a consumer is?"
#    - “Great! Consumers eat plants or other animals. And what about decomposers? Yes, they break down dead matter, returning nutrients to the soil. Let’s take a moment to think about local animals within these roles.”
#    - (Engage students and have them share examples related to their environment.)
#
# 3. **Food Chain Activity (25 minutes)**
#    - “Now, it’s time to create food chains! In groups, you will use pictures of different plants and animals to arrange them, showing how energy flows. Remember, every food chain starts with a producer!”
#    - (Distribute materials to groups, ensuring all students understand their tasks before they start)
#    - "You can also discuss the importance of each role while you work. I’ll circulate to help and answer questions."
#
# 4. **Interactive Game: Predator-Prey Simulation (25 minutes)**
#    - “Let’s bring our food chains to life with a game called 'Predator-Prey.' You will take roles as animals within an ecosystem! When I call out different animals, predators will chase the prey.”
#    - (Explain rules and designate areas for safe gameplay)
#    - “After the game, we’ll reflect on what we learned about the relationships between predators and prey!”
#
# 5. **Assessment: Drawing and Presenting Food Chains (30 minutes)**
#    - “For your final activity, draw a food chain from one specific ecosystem you are interested in. You’ll present it to the class and explain how energy flows through it.”
#    - (Provide clear guidelines and a rubric that outlines creativity, accuracy, and presentation clarity)
#    - “I’m excited to see your artistic and scientific skills in action!”
#
# 6. **Conclusion and Reflection (5 minutes)**
#    - “Fantastic presentations today! Each of you has done an excellent job understanding ecosystems and food chains. Before we end, let's take a moment for a quick reflection. On a sticky note, write down one thing you learned and one question you still have. This will be your exit ticket today!”
#    - (Collect the sticky notes as students exit)
#
# 7. **Wrap Up**
#    - “Great work today! Remember that understanding ecosystems is important for our planet. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!"
# </script>
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (e4f50302-b901-4c57-bba7-613cabbb19f8): Maximum turns (1) reached
#
#
# Curriculum summary:
#  A great topic for a fourth-grade science lesson would be "Ecosystems and Food Chains." This topic will engage students while helping them understand the relationships between living organisms and their environment.
#
# ### Lesson Overview:
# - **Objective:** Students will learn about different ecosystems, the roles of producers, consumers, and decomposers, and how energy flows through a food chain.
# - **Activities:**
#   - **Introduction to Ecosystems:** Discuss different types of ecosystems (forests, deserts, oceans) and the organisms that inhabit them.
#   - **Food Chain Diagram:** Students will create food chains using cut-out pictures of various plants and animals and arrange them in the correct order to show energy flow.
#   - **Interactive Game:** A "Predator-Prey" game where students take on roles of animals within an ecosystem to simulate food chains in action, emphasizing the importance of each role.
# - **Assessment:** Students will draw their own food chain from a specific ecosystem and present it to the class.
#
# This topic not only covers basic scientific concepts but also encourages creativity and interactive learning!
#
#
# Lesson Planner summary:
#  ### Revised Lesson Plan: Ecosystems and Food Chains
#
# #### Title:
# Ecosystems and Food Chains: Understanding Nature’s Web
#
# #### Learning Objectives:
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
#
# #### Materials Needed:
# - Pictures of various plants and animals (cut-outs or printed images)
# - Large poster board or drawing paper for food chain diagrams
# - Markers, crayons, and scissors
# - A space for the interactive game
# - Projector/whiteboard for discussion
# - Optional: Access to tablets/computers for digital food chain creation
#
# #### Script:
#
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re exploring ecosystems and food chains. Can anyone tell me what an ecosystem is?"
#    - (Pause for responses)
#    - “Fantastic answers! An ecosystem is a community of living organisms interacting with each other and their environment. Who can name an animal that lives in an ecosystem?”
#    - (Allow responses and then transition to identifying different ecosystems)
#    - “Let’s move on to talk about various ecosystems, such as forests, deserts, and oceans. I will show you some images of these environments.”
#
# 2. **Discussion of Ecosystems and Roles (15 minutes)**
#    - “Now, let’s discuss the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can share what a producer is?”
#    - (Listen to student responses)
#    - "Exactly! Producers are plants that make their own food. Can anyone tell me what a consumer is?"
#    - “Great! Consumers eat plants or other animals. And what about decomposers? Yes, they break down dead matter, returning nutrients to the soil. Let’s take a moment to think about local animals within these roles.”
#    - (Engage students and have them share examples related to their environment.)
#
# 3. **Food Chain Activity (25 minutes)**
#    - “Now, it’s time to create food chains! In groups, you will use pictures of different plants and animals to arrange them, showing how energy flows. Remember, every food chain starts with a producer!”
#    - (Distribute materials to groups, ensuring all students understand their tasks before they start)
#    - "You can also discuss the importance of each role while you work. I’ll circulate to help and answer questions."
#
# 4. **Interactive Game: Predator-Prey Simulation (25 minutes)**
#    - “Let’s bring our food chains to life with a game called 'Predator-Prey.' You will take roles as animals within an ecosystem! When I call out different animals, predators will chase the prey.”
#    - (Explain rules and designate areas for safe gameplay)
#    - “After the game, we’ll reflect on what we learned about the relationships between predators and prey!”
#
# 5. **Assessment: Drawing and Presenting Food Chains (30 minutes)**
#    - “For your final activity, draw a food chain from one specific ecosystem you are interested in. You’ll present it to the class and explain how energy flows through it.”
#    - (Provide clear guidelines and a rubric that outlines creativity, accuracy, and presentation clarity)
#    - “I’m excited to see your artistic and scientific skills in action!”
#
# 6. **Conclusion and Reflection (5 minutes)**
#    - “Fantastic presentations today! Each of you has done an excellent job understanding ecosystems and food chains. Before we end, let's take a moment for a quick reflection. On a sticky note, write down one thing you learned and one question you still have. This will be your exit ticket today!”
#    - (Collect the sticky notes as students exit)
#
# 7. **Wrap Up**
#    - “Great work today! Remember that understanding ecosystems is important for our planet. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!"
#
# ### Additional Suggestions:
# - **Differentiation:** Provide additional resources or simplified tasks for struggling learners and challenge advanced students with research tasks on complex ecosystems or current environmental issues.
# - **Technology Integration:** If feasible, consider allowing students to use tablets/computers to create digital food chains, enhancing engagement through technology.
# - **Local Ecosystem Connection:** Discuss local ecosystems or relevant environmental issues during the introduction or wrap-up to make learning relevant.
#
# These updates strengthen the lesson by enhancing clarity, ensuring adequate time for activities, and incorporating strategies for differentiation and technology engagement. Let me know if you have any other adjustments or additions to this plan!
#
#
# Formatter summary:
#  <title>Ecosystems and Food Chains: Understanding Nature’s Web</title>
# <learning_objectives>
# - Students will identify and describe different types of ecosystems and the organisms that inhabit them.
# - Students will explain the roles of producers, consumers, and decomposers within an ecosystem.
# - Students will demonstrate understanding of energy flow through food chains by creating visual food chain diagrams.
# - Students will engage in a collaborative role-playing activity to simulate predator-prey relationships within food chains.
# </learning_objectives>
# <script>
# 1. **Introduction (10 minutes)**
#    - "Good morning, class! Today, we’re exploring ecosystems and food chains. Can anyone tell me what an ecosystem is?"
#    - (Pause for responses)
#    - “Fantastic answers! An ecosystem is a community of living organisms interacting with each other and their environment. Who can name an animal that lives in an ecosystem?”
#    - (Allow responses and then transition to identifying different ecosystems)
#    - “Let’s move on to talk about various ecosystems, such as forests, deserts, and oceans. I will show you some images of these environments.”
#
# 2. **Discussion of Ecosystems and Roles (15 minutes)**
#    - “Now, let’s discuss the three main roles of organisms in ecosystems: producers, consumers, and decomposers. Who can share what a producer is?”
#    - (Listen to student responses)
#    - "Exactly! Producers are plants that make their own food. Can anyone tell me what a consumer is?"
#    - “Great! Consumers eat plants or other animals. And what about decomposers? Yes, they break down dead matter, returning nutrients to the soil. Let’s take a moment to think about local animals within these roles.”
#    - (Engage students and have them share examples related to their environment.)
#
# 3. **Food Chain Activity (25 minutes)**
#    - “Now, it’s time to create food chains! In groups, you will use pictures of different plants and animals to arrange them, showing how energy flows. Remember, every food chain starts with a producer!”
#    - (Distribute materials to groups, ensuring all students understand their tasks before they start)
#    - "You can also discuss the importance of each role while you work. I’ll circulate to help and answer questions."
#
# 4. **Interactive Game: Predator-Prey Simulation (25 minutes)**
#    - “Let’s bring our food chains to life with a game called 'Predator-Prey.' You will take roles as animals within an ecosystem! When I call out different animals, predators will chase the prey.”
#    - (Explain rules and designate areas for safe gameplay)
#    - “After the game, we’ll reflect on what we learned about the relationships between predators and prey!”
#
# 5. **Assessment: Drawing and Presenting Food Chains (30 minutes)**
#    - “For your final activity, draw a food chain from one specific ecosystem you are interested in. You’ll present it to the class and explain how energy flows through it.”
#    - (Provide clear guidelines and a rubric that outlines creativity, accuracy, and presentation clarity)
#    - “I’m excited to see your artistic and scientific skills in action!”
#
# 6. **Conclusion and Reflection (5 minutes)**
#    - “Fantastic presentations today! Each of you has done an excellent job understanding ecosystems and food chains. Before we end, let's take a moment for a quick reflection. On a sticky note, write down one thing you learned and one question you still have. This will be your exit ticket today!”
#    - (Collect the sticky notes as students exit)
#
# 7. **Wrap Up**
#    - “Great work today! Remember that understanding ecosystems is important for our planet. Next time, we’ll dive deeper into one specific ecosystem. Have a great day!"
# </script>

# %%
from autogen import ConversableAgent, GroupChatManager, GroupChat, LLMConfig

llm_config = LLMConfig(api_type="openai", model="gpt-4o-mini")

with llm_config:
    # Curriculum Standards Agent
    curriculum_agent = ConversableAgent(
        name="Curriculum_Agent",
        system_message="""You are a curriculum standards expert for fourth grade education.
        When given a topic, you provide relevant grade-level standards and learning objectives.
        Format every response as:
        STANDARDS:
        - [Standard 1]
        - [Standard 2]
        OBJECTIVES:
        - By the end of this lesson, students will be able to [objective 1]
        - By the end of this lesson, students will be able to [objective 2]""",
        human_input_mode="NEVER",
    )

    # Lesson Planner Agent
    lesson_planner_agent = ConversableAgent(
        name="Lesson_Planner_Agent",
        system_message="""You are a lesson planning specialist.
        Given standards and objectives, you create detailed lesson plans including:
        - Opening/Hook (5-10 minutes)
        - Main Activity (20-30 minutes)
        - Practice Activity (15-20 minutes)
        - Assessment/Closure (5-10 minutes)
        Format as a structured lesson plan with clear timing and materials needed.""",
        human_input_mode="NEVER",
    )

    # Lesson Reviewer Agent
    lesson_reviewer_agent = ConversableAgent(
        name="Lesson_Reviewer_Agent",
        system_message="""You are a lesson plan reviewer who ensures:
        1. Age-appropriate content and activities
        2. Alignment with provided standards
        3. Realistic timing
        4. Clear instructions
        5. Differentiation opportunities
        Provide specific feedback in these areas and suggest improvements if needed.""",
        human_input_mode="NEVER",
    )

    # Lead Teacher Agent
    lead_teacher_agent = ConversableAgent(
        name="Lead_Teacher_Agent",
        system_message="""You are an experienced fourth grade teacher who oversees the lesson planning process.
        Your role is to:
        1. Initiate the planning process with a clear topic
        2. Review and integrate feedback from other agents
        3. Ensure the final lesson plan is practical and engaging
        4. Make final adjustments based on classroom experience""",
        human_input_mode="NEVER",
    )

# Create the group chat for collaborative lesson planning
planning_chat = GroupChat(
    agents=[curriculum_agent, lesson_planner_agent, lesson_reviewer_agent],
    messages=[],
    max_round=4,
    send_introductions=True,
)

planning_manager = GroupChatManager(
    groupchat=planning_chat,
    llm_config=llm_config,
)

# Formatter of the final lesson plan to a standard format
formatter_message = """You are a lesson plan formatter. Format the complete plan as follows:
<title>Lesson plan title</title>
<standards>Standards covered</standards>
<learning_objectives>Key learning objectives</learning_objectives>
<materials>Materials required</materials>
<activities>Lesson plan activities</activities>
<assessment>Assessment details</assessment>
"""

with llm_config:
    lesson_formatter = ConversableAgent(
        name="formatter_agent",
        system_message=formatter_message,
    )

# Create nested chats configuration
nested_chats = [
    {
        # The first internal chat determines the standards and objectives
        # A round of revisions is supported with max_turns = 2
        "recipient": curriculum_agent,
        "message": lambda recipient, messages, sender, config: f"Please provide fourth grade standards and objectives for the topic: {messages[-1]['content']}",
        "max_turns": 2,
        "summary_method": "last_msg",
    },
    {
        # A group chat follows, where the lesson plan is created
        "recipient": planning_manager,
        "message": "Based on these standards and objectives, create a detailed lesson plan.",
        "max_turns": 1,
        "summary_method": "last_msg",
    },
    {
        # Finally, a two-agent chat formats the lesson plan
        # The result of this will be the lead_teacher_agent's reply
        "recipient": lesson_formatter,
        "message": "Format the lesson plan.",
        "max_turns": 1,
        "summary_method": "last_msg",
    }
]

# Register nested chats with the lead teacher
lead_teacher_agent.register_nested_chats(
    chat_queue=nested_chats,
    trigger=lambda sender: sender not in [curriculum_agent, planning_manager, lesson_reviewer_agent],
)

# A human-in-the-loop agent
human = ConversableAgent(
    name="human_agent",
    human_input_mode="ALWAYS"
)

# A two-agent chat between our human and the lead_teacher_agent
# to demonstrate the full workflow is within the one agent
result = lead_teacher_agent.initiate_chat(
    recipient=human,
    message="What topic would you like to get a lesson plan for?",
    max_turns=2
)

print("Final Lesson Plan:\n", result.summary)
# Out:
# Lead_Teacher_Agent (to human_agent):
#
# What topic would you like to get a lesson plan for?
#
# --------------------------------------------------------------------------------
# human_agent (to Lead_Teacher_Agent):
#
# Cosmology
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Lead_Teacher_Agent (to Curriculum_Agent):
#
# Please provide fourth grade standards and objectives for the topic: Cosmology
#
# --------------------------------------------------------------------------------
# Curriculum_Agent (to Lead_Teacher_Agent):
#
# STANDARDS:
# - NGSS 4-ESS1-1: Identify and explain the patterns of the sun, moon, and stars in the sky.
# - NGSS 4-ESS1-2: Use evidence from Earth’s features and patterns to construct an explanation for how the Earth and moon interact.
#
# OBJECTIVES:
# - By the end of this lesson, students will be able to identify and describe the key features of the solar system, including the sun, planets, moons, and other celestial bodies.
# - By the end of this lesson, students will be able to explain the effects of the Earth's rotation and revolution on day and night and the changing seasons.
#
# --------------------------------------------------------------------------------
# Lead_Teacher_Agent (to Curriculum_Agent):
#
# Great! We have clear standards and objectives to guide our lesson on Cosmology. We will focus on helping fourth graders understand the solar system and the relationship between the Earth and moon, along with the effects of rotation and revolution.
#
# ### Proposed Lesson Plan Outline
#
# **Topic**: Understanding Our Solar System
#
# **Grade Level**: Fourth Grade
#
# **Duration**: 1 hour
#
# **Standards**:
# - NGSS 4-ESS1-1: Identify and explain the patterns of the sun, moon, and stars in the sky.
# - NGSS 4-ESS1-2: Use evidence from Earth’s features and patterns to construct an explanation for how the Earth and moon interact.
#
# **Objectives**:
# 1. Students will identify and describe key features of the solar system: sun, planets, moons, and other celestial bodies.
# 2. Students will explain how Earth's rotation and revolution affect day and night and the changing seasons.
#
# ### Introduction (10 minutes)
# - Begin with a brief discussion on what students already know about the solar system.
# - Show a short video clip that provides an overview of the solar system.
#
# ### Lesson Activities (40 minutes)
#
# **Activity 1: Solar System Exploration (20 minutes)**
# - Divide students into small groups and provide each group with images and facts about different celestial bodies (sun, planets, moons).
# - Each group will create a mini-poster describing their assigned celestial body and present it to the class.
#
# **Activity 2: Earth’s Movement (20 minutes)**
# - Use a globe and flashlight to demonstrate Earth's rotation (day and night) and revolution (seasons).
# - Have students conduct an experiment using a simple model to see how the tilt of the Earth’s axis affects seasons.
# - In pairs, students will discuss and write down the effects of Earth’s movements on their daily lives (e.g., what time it gets dark, how seasons change).
#
# ### Conclusion (10 minutes)
# - Review key points discussed during the lesson.
# - Encourage students to ask questions or share something new they learned.
# - Assign a follow-up activity where students will think about the night sky at home and keep a journal of what they observe over a week.
#
# ### Assessment:
# - Monitor group participation and understanding during activities.
# - Use a quick quiz on key concepts at the end of the lesson to assess knowledge.
#
# ### Extensions:
# - Consider incorporating technology by using apps or online resources for students to explore the solar system further.
#
# ### Integration of Feedback:
# Now, I’ll gather feedback from other agents who might have insights or suggestions for further enhancing this lesson plan.
#
# --------------------------------------------------------------------------------
# Curriculum_Agent (to Lead_Teacher_Agent):
#
# That sounds like a well-structured lesson plan on cosmology! Here are some suggestions to enhance it further based on best practices:
#
# ### Additional Strategies for Improvement:
#
# 1. **Technology Integration**:
#    - **Interactive Simulations**: Incorporate software or websites like NASA's Eyes on the Solar System or SpacePlace, where students can interactively explore planets and moons.
#
# 2. **Differentiation**:
#    - **Choice Boards**: For the mini-poster activity, provide students options (writing, drawing, technology-based) to cater to different learning styles.
#    - **Tiered Assignments**: Create varying levels of complexity in the discussion prompts regarding Earth's movements, allowing advanced students to explore more intricate concepts like gravitational pull.
#
# 3. **Cross-Disciplinary Links**:
#    - **Art Integration**: After the mini-poster creations, consider a follow-up art project where students design their own imaginary planet, detailing climate, terrain, and possible life forms.
#    - **Math Integration**: Introduce simple calculations related to distances in the solar system or the time it takes for light from the sun to reach Earth.
#
# 4. **Assessment Diversification**:
#    - **Exit Tickets**: At the end of the lesson, have each student write one thing they learned and one question they still have about the solar system, which can guide future lessons.
#    - **Peer Assessments**: After group presentations, allow students to provide constructive feedback or quizzes to each other based on the presentations they heard.
#
# 5. **Real-World Applications**:
#    - Discuss space exploration and current missions (like Mars rovers or lunar explorations) to make connections between the lesson and real-world science.
#    - Invite a guest speaker, such as an astronomer or science educator, to discuss current discoveries in cosmology.
#
# By incorporating these strategies, your lesson on understanding our solar system could become even more engaging and informative for the fourth-grade students, enhancing their overall learning experience.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (3f00d781-7940-4681-8ac5-00fe24310c28): Maximum turns (2) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Lead_Teacher_Agent (to chat_manager):
#
# Based on these standards and objectives, create a detailed lesson plan.
# Context:
# That sounds like a well-structured lesson plan on cosmology! Here are some suggestions to enhance it further based on best practices:
#
# ### Additional Strategies for Improvement:
#
# 1. **Technology Integration**:
#    - **Interactive Simulations**: Incorporate software or websites like NASA's Eyes on the Solar System or SpacePlace, where students can interactively explore planets and moons.
#
# 2. **Differentiation**:
#    - **Choice Boards**: For the mini-poster activity, provide students options (writing, drawing, technology-based) to cater to different learning styles.
#    - **Tiered Assignments**: Create varying levels of complexity in the discussion prompts regarding Earth's movements, allowing advanced students to explore more intricate concepts like gravitational pull.
#
# 3. **Cross-Disciplinary Links**:
#    - **Art Integration**: After the mini-poster creations, consider a follow-up art project where students design their own imaginary planet, detailing climate, terrain, and possible life forms.
#    - **Math Integration**: Introduce simple calculations related to distances in the solar system or the time it takes for light from the sun to reach Earth.
#
# 4. **Assessment Diversification**:
#    - **Exit Tickets**: At the end of the lesson, have each student write one thing they learned and one question they still have about the solar system, which can guide future lessons.
#    - **Peer Assessments**: After group presentations, allow students to provide constructive feedback or quizzes to each other based on the presentations they heard.
#
# 5. **Real-World Applications**:
#    - Discuss space exploration and current missions (like Mars rovers or lunar explorations) to make connections between the lesson and real-world science.
#    - Invite a guest speaker, such as an astronomer or science educator, to discuss current discoveries in cosmology.
#
# By incorporating these strategies, your lesson on understanding our solar system could become even more engaging and informative for the fourth-grade students, enhancing their overall learning experience.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Lesson_Planner_Agent
#
# Lesson_Planner_Agent (to chat_manager):
#
# STANDARDS:
# - Next Generation Science Standards (NGSS) 4-ESS1-1: Identify and explain how the Earth and the Moon change relative to one another and to the Sun.
# - Common Core State Standards (CCSS) for Reading Informational Text 4.RI.7: Interpret information presented visually (e.g., in charts, graphs, diagrams, timelines, animations, or interactive elements).
#
# OBJECTIVES:
# - By the end of this lesson, students will be able to describe the movements of the Earth and Moon in relation to the Sun.
# - By the end of this lesson, students will be able to create a visual representation (mini-poster) demonstrating a specific aspect of the solar system.
#
# ### Lesson Plan: Exploring the Solar System
#
# **Grade Level**: 4th Grade
# **Duration**: 60-70 minutes
# **Materials Needed**:
# - Whiteboard and markers
# - Projector and computer for presentations
# - Access to websites (NASA’s Eyes on the Solar System, SpacePlace) for interactive exploration
# - Poster boards, markers, colored pencils, and craft supplies
# - Worksheets with discussion prompts
# - Exit ticket cards
#
# ---
#
# #### Opening/Hook (5-10 minutes)
# 1. **Engage students with a short video** showcasing the solar system, emphasizing the movement of the Earth, Moon, and Sun.
# 2. **Discussion Prompt**: Ask students, "What do you think makes the day and night cycle?" to activate their prior knowledge.
#
# #### Main Activity (20-30 minutes)
# 1. **Introduction to Concepts**: Briefly explain the Earth’s rotation and revolution around the Sun, as well as the Moon’s orbit around the Earth.
# 2. **Group Work**: Divide students into small groups and assign each group a planet or moon to research using interactive simulations. Students will gather information on their assigned celestial body, focusing on its movements and characteristics.
# 3. **Mini-Poster Creation**: Groups will create a mini-poster that includes:
#    - Name of the celestial body
#    - Illustrations showing its movement
#    - Key facts about its relation to the Sun and Earth
#
# #### Practice Activity (15-20 minutes)
# 1. **Gallery Walk**: Groups will display their mini-posters around the classroom. As students walk around, they’ll fill out a peer assessment worksheet that includes:
#    - One interesting fact learned from each poster
#    - One question about the poster
# 2. **Digital Component**: Students can also use technology to create a digital version of their poster using a simple presentation tool if time allows.
#
# #### Assessment/Closure (5-10 minutes)
# 1. **Exit Ticket**: Each student will write down one thing they learned about the solar system and one question they still have.
# 2. **Class Discussion**: Briefly share some of the questions from the exit tickets to check for understanding and to guide future lessons.
#
# ---
#
# ### Adaptations and Extensions:
# - **Differentiation**: Allow students to choose between visual, written, or digital presentations for their mini-posters based on their strengths.
# - **Cross-Disciplinary Connections**: Incorporate a math activity such as calculating distances between celestial bodies or understanding the scale of the solar system.
# - **Art Integration**: Follow up with an art project where students create their own planet, focusing on creative aspects and imaginative possibilities.
#
# By engaging students actively and using a variety of instructional strategies, this lesson plan aims to deepen their understanding of cosmology while catering to different learning styles and interests.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Lesson_Reviewer_Agent
#
# Lesson_Reviewer_Agent (to chat_manager):
#
# ### Lesson Plan Reviewer Feedback
#
# **1. Age-appropriate content and activities**:
# - The content is appropriately tailored for 4th graders, focusing on the basic movements of celestial bodies and their relationships, which aligns well with students' developmental stage. The activities (e.g., creating mini-posters, group work) are engaging and suit their interests. **No adjustments needed.**
#
# **2. Alignment with provided standards**:
# - The lesson clearly aligns with the Next Generation Science Standards (NGSS) and Common Core State Standards (CCSS) specified. The main activities directly tie into the standards, supporting both scientific understanding and reading comprehension skills. However, consider including some elements of engineering or design thinking if applicable in your context, which may enhance alignment with NGSS. **Minor suggestion for variety in standards connection.**
#
# **3. Realistic timing**:
# - The total estimated time for the lesson (60-70 minutes) appears realistic based on the complexity of the tasks. However, depending on the group size, the gallery walk may need additional time, or the mini-poster creation process may need to be streamlined to ensure students remain on task. It might be practical to allot specific times for each group activity in the Main Activity section. **Suggestion: Add specific time limits to portions of group work for clarity.**
#
# **4. Clear instructions**:
# - The instructions for each part of the lesson are mostly clear, providing a good framework for both teachers and students. However, consider clarifying the expectations for the mini-poster more explicitly (e.g., size requirements, number of facts) to ensure all groups produce work of similar depth and quality. Adding an example poster could also help. **Suggestion: Include an example or rubric for the mini-poster.**
#
# **5. Differentiation opportunities**:
# - The lesson effectively considers different learning styles through group work and creative poster-making options. The use of technology (digital version of posters) is particularly beneficial for engaging diverse learners. Furthermore, offering tiered discussion prompts is an excellent idea for challenging advanced students. Consider elaborating on potential supports for students who may struggle (e.g., sentence starters or visuals for those needing extra guidance). **Suggestion: Provide more specific supports for struggling students.**
#
# ### Overall Summary:
# This lesson plan is well-structured and engaging for 4th graders, with clear objectives tied to appropriate standards. Incorporating the suggested improvements for clarity and support can further enhance the learning experience, ensuring effective teaching outcomes. Great job overall!
#
# --------------------------------------------------------------------------------
#
# Next speaker: Lesson_Planner_Agent
#
# Lesson_Planner_Agent (to chat_manager):
#
# Thank you for your detailed feedback! Below are the suggested revisions and enhancements to the lesson plan based on your insights:
#
# ### Revised Lesson Plan: Exploring the Solar System
#
# **Grade Level**: 4th Grade
# **Duration**: 60-70 minutes
# **Materials Needed**:
# - Whiteboard and markers
# - Projector and computer for presentations
# - Access to websites (NASA’s Eyes on the Solar System, SpacePlace) for interactive exploration
# - Poster boards, markers, colored pencils, and craft supplies
# - Worksheets with discussion prompts
# - Exit ticket cards
# - Example mini-poster for reference
# - Rubric for mini-poster assessment
# - Sentence starters and visuals for struggling students
#
# ---
#
# #### Opening/Hook (5-10 minutes)
# 1. **Engage students with a short video** showcasing the solar system, emphasizing the movement of the Earth, Moon, and Sun.
# 2. **Discussion Prompt**: Ask students, "What do you think makes the day and night cycle?" to activate their prior knowledge.
#
# #### Main Activity (20-30 minutes)
# 1. **Introduction to Concepts**: Briefly explain the Earth’s rotation and revolution around the Sun, as well as the Moon’s orbit around the Earth.
# 2. **Group Work**: Divide students into small groups (4-5 students) and assign each group a celestial body (e.g., Earth, Moon, Mars, etc.).
#    - **Specific Time Frames**: Allocate 10 minutes for research using interactive simulations and 15 minutes for mini-poster creation.
# 3. **Mini-Poster Creation**:
#    - Each group will create a mini-poster that includes:
#      - Name of the celestial body
#      - Illustrations showing its movement
#      - At least three key facts about its relation to the Sun and Earth
#    - Provide an **example mini-poster** for students to reference and include a **rubric** outlining expectations for content and presentation.
#
# #### Practice Activity (15-20 minutes)
# 1. **Gallery Walk**: Groups will display their mini-posters around the classroom. As students walk around, they’ll fill out a peer assessment worksheet that includes:
#    - One interesting fact learned from each poster
#    - One question about the poster
# 2. **Digital Component**: Students can also use technology to create a digital version of their poster using a simple presentation tool if time allows.
#
# #### Assessment/Closure (5-10 minutes)
# 1. **Exit Ticket**: Each student will write down one thing they learned about the solar system and one question they still have.
# 2. **Class Discussion**: Briefly share some of the questions from the exit tickets to check for understanding and to guide future lessons.
#
# ---
#
# ### Adaptations and Extensions:
# - **Differentiation**:
#    - **Supports for Struggling Students**: Provide sentence starters for group discussions and visuals for each celestial body to assist with information processing.
#    - **Advanced Learner Challenges**: Include prompts for advanced learners to explore concepts like gravitational forces or comparisons of sizes and distances between celestial bodies.
# - **Cross-Disciplinary Connections**: Incorporate a math activity such as calculating distances between celestial bodies or understanding the scale of the solar system.
# - **Art Integration**: Follow up with an art project where students create their own planet with fictional climates and terrains.
#
# ### Final Note:
# These revisions aim to clarify expectations and enhance support for diverse learners while maintaining the engaging quality of the lesson. Thank you for the constructive feedback, and I look forward to seeing how this lesson unfolds in the classroom!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (2876cf39-cc7b-4ad2-9666-446d871da21e): Maximum rounds (4) reached
#
# >>>>>>>> TERMINATING RUN (fdf46539-7a60-4c0e-b92f-0a442c27f24b): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# Lead_Teacher_Agent (to formatter_agent):
#
# Format the lesson plan.
# Context:
# That sounds like a well-structured lesson plan on cosmology! Here are some suggestions to enhance it further based on best practices:
#
# ### Additional Strategies for Improvement:
#
# 1. **Technology Integration**:
#    - **Interactive Simulations**: Incorporate software or websites like NASA's Eyes on the Solar System or SpacePlace, where students can interactively explore planets and moons.
#
# 2. **Differentiation**:
#    - **Choice Boards**: For the mini-poster activity, provide students options (writing, drawing, technology-based) to cater to different learning styles.
#    - **Tiered Assignments**: Create varying levels of complexity in the discussion prompts regarding Earth's movements, allowing advanced students to explore more intricate concepts like gravitational pull.
#
# 3. **Cross-Disciplinary Links**:
#    - **Art Integration**: After the mini-poster creations, consider a follow-up art project where students design their own imaginary planet, detailing climate, terrain, and possible life forms.
#    - **Math Integration**: Introduce simple calculations related to distances in the solar system or the time it takes for light from the sun to reach Earth.
#
# 4. **Assessment Diversification**:
#    - **Exit Tickets**: At the end of the lesson, have each student write one thing they learned and one question they still have about the solar system, which can guide future lessons.
#    - **Peer Assessments**: After group presentations, allow students to provide constructive feedback or quizzes to each other based on the presentations they heard.
#
# 5. **Real-World Applications**:
#    - Discuss space exploration and current missions (like Mars rovers or lunar explorations) to make connections between the lesson and real-world science.
#    - Invite a guest speaker, such as an astronomer or science educator, to discuss current discoveries in cosmology.
#
# By incorporating these strategies, your lesson on understanding our solar system could become even more engaging and informative for the fourth-grade students, enhancing their overall learning experience.
# Based on these standards and objectives, create a detailed lesson plan.
# Context:
# That sounds like a well-structured lesson plan on cosmology! Here are some suggestions to enhance it further based on best practices:
#
# ### Additional Strategies for Improvement:
#
# 1. **Technology Integration**:
#    - **Interactive Simulations**: Incorporate software or websites like NASA's Eyes on the Solar System or SpacePlace, where students can interactively explore planets and moons.
#
# 2. **Differentiation**:
#    - **Choice Boards**: For the mini-poster activity, provide students options (writing, drawing, technology-based) to cater to different learning styles.
#    - **Tiered Assignments**: Create varying levels of complexity in the discussion prompts regarding Earth's movements, allowing advanced students to explore more intricate concepts like gravitational pull.
#
# 3. **Cross-Disciplinary Links**:
#    - **Art Integration**: After the mini-poster creations, consider a follow-up art project where students design their own imaginary planet, detailing climate, terrain, and possible life forms.
#    - **Math Integration**: Introduce simple calculations related to distances in the solar system or the time it takes for light from the sun to reach Earth.
#
# 4. **Assessment Diversification**:
#    - **Exit Tickets**: At the end of the lesson, have each student write one thing they learned and one question they still have about the solar system, which can guide future lessons.
#    - **Peer Assessments**: After group presentations, allow students to provide constructive feedback or quizzes to each other based on the presentations they heard.
#
# 5. **Real-World Applications**:
#    - Discuss space exploration and current missions (like Mars rovers or lunar explorations) to make connections between the lesson and real-world science.
#    - Invite a guest speaker, such as an astronomer or science educator, to discuss current discoveries in cosmology.
#
# By incorporating these strategies, your lesson on understanding our solar system could become even more engaging and informative for the fourth-grade students, enhancing their overall learning experience.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# formatter_agent (to Lead_Teacher_Agent):
#
# <title>Exploring Our Solar System</title>
# <standards>NGSS 4-ESS1-1: Earth's Place in the Universe; NGSS 4-ESS2-2: Earth Systems; ISTE Standard for Students 5: Computational Thinking</standards>
# <learning_objectives>1. Students will identify and describe the planets in our solar system. 2. Students will understand the movements of Earth and its relationship to the sun. 3. Students will create a mini-poster summarizing information about a chosen planet. 4. Students will engage in discussions utilizing scientific vocabulary.</learning_objectives>
# <materials>1. Computers or tablets with internet access 2. Art supplies (poster boards, markers, colored pencils) 3. Access to NASA's Eyes on the Solar System or SpacePlace 4. Calculation worksheets (for math integration) 5. Exit ticket templates</materials>
# <activities>1. Introduction (10 minutes): Briefly introduce the solar system using videos and images. Discuss the focus of the lesson. 2. Interactive Exploration (20 minutes): Allow students to explore NASA's Eyes on the Solar System or SpacePlace, observing details about the planets. 3. Group Discussion (15 minutes): Facilitate discussions about Earth's movements and the importance of the sun. Introduce tiered assignments based on students' understanding. 4. Mini-Poster Activity (30 minutes): Students will create a mini-poster on a planet of their choice, providing options for how they showcase their knowledge (writing, drawing, or a tech-based presentation). 5. Art Project (Optional) (20 minutes): Students design an imaginary planet, detailing climate, terrain, and possible life forms. 6. Math Activity (15 minutes): Introduce simple calculations related to distances in the solar system, such as figuring out how long it takes light from the sun to reach Earth. 7. Presentations (15 minutes): Students present their mini-posters and imaginary planets to the class.</activities>
# <assessment>1. Exit Tickets: Each student will submit an exit ticket stating one thing they learned and one question they still have about the solar system. 2. Peer Assessments: After presentations, students will provide constructive feedback to their peers. 3. Teacher Observation: Informal assessment during group discussions and activities to ensure understanding and engagement.</assessment>
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0eb12ddf-706b-4eb2-8f73-9b2a8353c8da): Maximum turns (1) reached
# Lead_Teacher_Agent (to human_agent):
#
# <title>Exploring Our Solar System</title>
# <standards>NGSS 4-ESS1-1: Earth's Place in the Universe; NGSS 4-ESS2-2: Earth Systems; ISTE Standard for Students 5: Computational Thinking</standards>
# <learning_objectives>1. Students will identify and describe the planets in our solar system. 2. Students will understand the movements of Earth and its relationship to the sun. 3. Students will create a mini-poster summarizing information about a chosen planet. 4. Students will engage in discussions utilizing scientific vocabulary.</learning_objectives>
# <materials>1. Computers or tablets with internet access 2. Art supplies (poster boards, markers, colored pencils) 3. Access to NASA's Eyes on the Solar System or SpacePlace 4. Calculation worksheets (for math integration) 5. Exit ticket templates</materials>
# <activities>1. Introduction (10 minutes): Briefly introduce the solar system using videos and images. Discuss the focus of the lesson. 2. Interactive Exploration (20 minutes): Allow students to explore NASA's Eyes on the Solar System or SpacePlace, observing details about the planets. 3. Group Discussion (15 minutes): Facilitate discussions about Earth's movements and the importance of the sun. Introduce tiered assignments based on students' understanding. 4. Mini-Poster Activity (30 minutes): Students will create a mini-poster on a planet of their choice, providing options for how they showcase their knowledge (writing, drawing, or a tech-based presentation). 5. Art Project (Optional) (20 minutes): Students design an imaginary planet, detailing climate, terrain, and possible life forms. 6. Math Activity (15 minutes): Introduce simple calculations related to distances in the solar system, such as figuring out how long it takes light from the sun to reach Earth. 7. Presentations (15 minutes): Students present their mini-posters and imaginary planets to the class.</activities>
# <assessment>1. Exit Tickets: Each student will submit an exit ticket stating one thing they learned and one question they still have about the solar system. 2. Peer Assessments: After presentations, students will provide constructive feedback to their peers. 3. Teacher Observation: Informal assessment during group discussions and activities to ensure understanding and engagement.</assessment>
#
# --------------------------------------------------------------------------------
# human_agent (to Lead_Teacher_Agent):
#
# sounds good!
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (9e34195f-9446-4eda-a0da-9a2ec2b506ba): Maximum turns (2) reached
# Final Lesson Plan:
#  sounds good!

# %%
from autogen import (
    AfterWork,
    OnCondition,
    AfterWorkOption,
    ConversableAgent,
    SwarmResult,
    initiate_swarm_chat,
    register_hand_off,
    LLMConfig,
)

llm_config = LLMConfig(api_type="openai", model="gpt-4o", cache_seed=None)

# 1. Context
shared_context = {
    "lesson_plans": [],
    "lesson_reviews": [],
    # Will be decremented, resulting in 0 (aka False) when no reviews are left
    "reviews_left": 2,
}

# 2. Functions
def record_plan(lesson_plan: str, context_variables: dict) -> SwarmResult:
    """Record the lesson plan"""
    context_variables["lesson_plans"].append(lesson_plan)

    # Returning the updated context so the shared context can be updated
    return SwarmResult(context_variables=context_variables)

def record_review(lesson_review: str, context_variables: dict) -> SwarmResult:
    """After a review has been made, increment the count of reviews"""
    context_variables["lesson_reviews"].append(lesson_review)
    context_variables["reviews_left"] -= 1

    # Controlling the flow to the next agent from a tool call
    return SwarmResult(
        agent=teacher if context_variables["reviews_left"] < 0 else lesson_planner, context_variables=context_variables
    )

planner_message = """You are a classroom lesson planner.
Given a topic, write a lesson plan for a fourth grade class.
If you are given revision feedback, update your lesson plan and record it.
Use the following format:
<title>Lesson plan title</title>
<learning_objectives>Key learning objectives</learning_objectives>
<script>How to introduce the topic to the kids</script>
"""

reviewer_message = """You are a classroom lesson reviewer.
You compare the lesson plan to the fourth grade curriculum
and provide a maximum of 3 recommended changes for each review.
Always provide feedback for the current lesson plan.
"""

teacher_message = """You are a classroom teacher.
You decide topics for lessons and work with a lesson planner.
and reviewer to create and finalise lesson plans.
"""

# 3. Our agents now have tools to use (functions above)
with llm_config:
    lesson_planner = ConversableAgent(name="planner_agent", system_message=planner_message, functions=[record_plan])

    lesson_reviewer = ConversableAgent(name="reviewer_agent", system_message=reviewer_message, functions=[record_review])

    teacher = ConversableAgent(name="teacher_agent", system_message=teacher_message)

# 4. Transitions using hand-offs

# Lesson planner will create a plan and hand off to the reviewer if we're still
# allowing reviews. After that's done, transition to the teacher.
register_hand_off(lesson_planner,
    [
        OnCondition(
            target=lesson_reviewer,
            condition="After creating/updating and recording the plan, it must be reviewed.",
            available="reviews_left",
        ),
        AfterWork(agent=teacher),
    ]
)

# Lesson reviewer will review the plan and return control to the planner if there's
# no plan to review, otherwise it will provide a review and
register_hand_off(lesson_reviewer,
    [
        OnCondition(
            target=lesson_planner, condition="After new feedback has been made and recorded, the plan must be updated."
        ),
        AfterWork(agent=teacher),
    ]
)

# Teacher works with the lesson planner to create a plan. When control returns to them and
# a plan exists, they'll end the swarm.
register_hand_off(teacher,
    [
        OnCondition(target=lesson_planner, condition="Create a lesson plan.", available="reviews_left"),
        AfterWork(AfterWorkOption.TERMINATE),
    ]
)

# 5. Run the Swarm which returns the chat and updated context variables
chat_result, context_variables, last_agent = initiate_swarm_chat(
    initial_agent=teacher,
    agents=[lesson_planner, lesson_reviewer, teacher],
    messages="Today, let's introduce our kids to the solar system.",
    context_variables=shared_context,
)

print(f"Number of reviews: {len(context_variables['lesson_reviews'])}")
print(f"Reviews remaining: {context_variables['reviews_left']}")
print(f"Final Lesson Plan:\n{context_variables['lesson_plans'][-1]}")
# Out:
# _User (to chat_manager):
#
# Today, let's introduce our kids to the solar system.
#
# --------------------------------------------------------------------------------
#
# Next speaker: teacher_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# teacher_agent (to chat_manager):
#
# ***** Suggested tool call (call_J5jVQAp4pkTKgNfgAFIpf60A): transfer_teacher_agent_to_planner_agent *****
# Arguments:
# {}
# ********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_teacher_agent_to_planner_agent...
# Call ID: call_J5jVQAp4pkTKgNfgAFIpf60A
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_J5jVQAp4pkTKgNfgAFIpf60A) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: planner_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to chat_manager):
#
# <title>Lesson plan title</title>
# Exploring the Solar System
#
# <learning_objectives>Key learning objectives</learning_objectives>
# 1. Understand the basic structure of the solar system, including the Sun, planets, and other celestial bodies.
# 2. Identify the names and order of the planets in the solar system.
# 3. Learn interesting facts about each planet.
# 4. Develop an appreciation for the scale and diversity of the solar system.
#
# <script>How to introduce the topic to the kids</script>
# 1. **Introduction (10 minutes)**
#    - Begin by asking the students if they have ever looked up at the night sky and wondered what is out there.
#    - Explain that today, we're going on an exciting journey through our solar system to explore the amazing worlds that exist beyond Earth.
#
# 2. **Presentation (15 minutes)**
#    - Use a visual presentation or video to introduce the solar system, starting with the Sun and moving outward to the planets.
#    - Highlight key facts about each planet, such as size, color, distance from the Sun, and any unique features (e.g., rings of Saturn or the red surface of Mars).
#
# 3. **Activity (20 minutes)**
#    - Divide the class into groups and assign each group a planet or celestial body (e.g., moons, asteroids).
#    - Provide resource materials or internet access for students to research their assigned planet.
#    - Ask each group to create a poster with interesting facts and a drawing or representation of their assigned body.
#
# 4. **Group Presentations (15 minutes)**
#    - Have each group present their poster to the class, sharing what they've learned about their assigned planet or celestial body.
#
# 5. **Conclusion (5 minutes)**
#    - Recap the main points of the lesson, emphasizing the diversity and wonders of our solar system.
#    - Encourage students to continue exploring and learning about space.
#
# 6. **Q&A (5 minutes)**
#    - Allow time for students to ask questions or share thoughts about what they found most interesting.
#
# This lesson aims to spark curiosity and a sense of wonder about the universe among the students. Through interactive activities and group work, they will retain what they've learned about the solar system more effectively.
#
# --------------------------------------------------------------------------------
#
# Next speaker: teacher_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# teacher_agent (to chat_manager):
#
# ***** Suggested tool call (call_suxQQ9YlEivdkomKWa4I4ron): transfer_teacher_agent_to_planner_agent *****
# Arguments:
# {}
# ********************************************************************************************************
# ***** Suggested tool call (call_MGqc6F1EuIVuTsT9GzqxpN5H): transfer_teacher_agent_to_planner_agent *****
# Arguments:
# {}
# ********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_teacher_agent_to_planner_agent...
# Call ID: call_suxQQ9YlEivdkomKWa4I4ron
# Input arguments: {}
#
# >>>>>>>> EXECUTING FUNCTION transfer_teacher_agent_to_planner_agent...
# Call ID: call_MGqc6F1EuIVuTsT9GzqxpN5H
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_suxQQ9YlEivdkomKWa4I4ron) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_MGqc6F1EuIVuTsT9GzqxpN5H) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: planner_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to chat_manager):
#
# ***** Suggested tool call (call_7ba6KfcDu4ascafR6iU8WUTJ): record_plan *****
# Arguments:
# {"lesson_plan": "<title>Exploring the Solar System</title>\n<learning_objectives>Key learning objectives</learning_objectives>\n1. Understand the basic structure of the solar system, including the Sun, planets, and other celestial bodies.\n2. Identify the names and order of the planets in the solar system.\n3. Learn interesting facts about each planet.\n4. Develop an appreciation for the scale and diversity of the solar system.\n\n<script>How to introduce the topic to the kids</script>\n1. **Introduction (10 minutes)**\n   - Begin by asking the students if they have ever looked up at the night sky and wondered what is out there.\n   - Explain that today, we're going on an exciting journey through our solar system to explore the amazing worlds that exist beyond Earth.\n\n2. **Presentation (15 minutes)**\n   - Use a visual presentation or video to introduce the solar system, starting with the Sun and moving outward to the planets.\n   - Highlight key facts about each planet, such as size, color, distance from the Sun, and any unique features (e.g., rings of Saturn or the red surface of Mars).\n\n3. **Activity (20 minutes)**\n   - Divide the class into groups and assign each group a planet or celestial body (e.g., moons, asteroids).\n   - Provide resource materials or internet access for students to research their assigned planet.\n   - Ask each group to create a poster with interesting facts and a drawing or representation of their assigned body.\n\n4. **Group Presentations (15 minutes)**\n   - Have each group present their poster to the class, sharing what they've learned about their assigned planet or celestial body.\n\n5. **Conclusion (5 minutes)**\n   - Recap the main points of the lesson, emphasizing the diversity and wonders of our solar system.\n   - Encourage students to continue exploring and learning about space.\n\n6. **Q&A (5 minutes)**\n   - Allow time for students to ask questions or share thoughts about what they found most interesting.\n\nThis lesson aims to spark curiosity and a sense of wonder about the universe among the students. Through interactive activities and group work, they will retain what they've learned about the solar system more effectively."}
# ****************************************************************************
# ***** Suggested tool call (call_4gPNKBrojjycskPo2Xalirb4): transfer_planner_agent_to_reviewer_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION record_plan...
# Call ID: call_7ba6KfcDu4ascafR6iU8WUTJ
# Input arguments: {'lesson_plan': "<title>Exploring the Solar System</title>\n<learning_objectives>Key learning objectives</learning_objectives>\n1. Understand the basic structure of the solar system, including the Sun, planets, and other celestial bodies.\n2. Identify the names and order of the planets in the solar system.\n3. Learn interesting facts about each planet.\n4. Develop an appreciation for the scale and diversity of the solar system.\n\n<script>How to introduce the topic to the kids</script>\n1. **Introduction (10 minutes)**\n   - Begin by asking the students if they have ever looked up at the night sky and wondered what is out there.\n   - Explain that today, we're going on an exciting journey through our solar system to explore the amazing worlds that exist beyond Earth.\n\n2. **Presentation (15 minutes)**\n   - Use a visual presentation or video to introduce the solar system, starting with the Sun and moving outward to the planets.\n   - Highlight key facts about each planet, such as size, color, distance from the Sun, and any unique features (e.g., rings of Saturn or the red surface of Mars).\n\n3. **Activity (20 minutes)**\n   - Divide the class into groups and assign each group a planet or celestial body (e.g., moons, asteroids).\n   - Provide resource materials or internet access for students to research their assigned planet.\n   - Ask each group to create a poster with interesting facts and a drawing or representation of their assigned body.\n\n4. **Group Presentations (15 minutes)**\n   - Have each group present their poster to the class, sharing what they've learned about their assigned planet or celestial body.\n\n5. **Conclusion (5 minutes)**\n   - Recap the main points of the lesson, emphasizing the diversity and wonders of our solar system.\n   - Encourage students to continue exploring and learning about space.\n\n6. **Q&A (5 minutes)**\n   - Allow time for students to ask questions or share thoughts about what they found most interesting.\n\nThis lesson aims to spark curiosity and a sense of wonder about the universe among the students. Through interactive activities and group work, they will retain what they've learned about the solar system more effectively."}
#
# >>>>>>>> EXECUTING FUNCTION transfer_planner_agent_to_reviewer_agent...
# Call ID: call_4gPNKBrojjycskPo2Xalirb4
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_7ba6KfcDu4ascafR6iU8WUTJ) *****
#
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_4gPNKBrojjycskPo2Xalirb4) *****
# Swarm agent --> reviewer_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: reviewer_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# reviewer_agent (to chat_manager):
#
# ***** Suggested tool call (call_z3s4MUZWSILfRJdwseMptZ9J): transfer_reviewer_agent_to_planner_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_reviewer_agent_to_planner_agent...
# Call ID: call_z3s4MUZWSILfRJdwseMptZ9J
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_z3s4MUZWSILfRJdwseMptZ9J) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: planner_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to chat_manager):
#
# ***** Suggested tool call (call_INjJM1l04mpqPdXieYOd42rb): transfer_planner_agent_to_reviewer_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_planner_agent_to_reviewer_agent...
# Call ID: call_INjJM1l04mpqPdXieYOd42rb
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_INjJM1l04mpqPdXieYOd42rb) *****
# Swarm agent --> reviewer_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: reviewer_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# reviewer_agent (to chat_manager):
#
# ***** Suggested tool call (call_z3s4MUZWSILfRJdwseMptZ9J): transfer_reviewer_agent_to_planner_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_reviewer_agent_to_planner_agent...
# Call ID: call_z3s4MUZWSILfRJdwseMptZ9J
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_z3s4MUZWSILfRJdwseMptZ9J) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: planner_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to chat_manager):
#
# ***** Suggested tool call (call_INjJM1l04mpqPdXieYOd42rb): transfer_planner_agent_to_reviewer_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_planner_agent_to_reviewer_agent...
# Call ID: call_INjJM1l04mpqPdXieYOd42rb
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_INjJM1l04mpqPdXieYOd42rb) *****
# Swarm agent --> reviewer_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: reviewer_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# reviewer_agent (to chat_manager):
#
# ***** Suggested tool call (call_z3s4MUZWSILfRJdwseMptZ9J): transfer_reviewer_agent_to_planner_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_reviewer_agent_to_planner_agent...
# Call ID: call_z3s4MUZWSILfRJdwseMptZ9J
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_z3s4MUZWSILfRJdwseMptZ9J) *****
# Swarm agent --> planner_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: planner_agent
#
#
# >>>>>>>> USING AUTO REPLY...
# planner_agent (to chat_manager):
#
# ***** Suggested tool call (call_INjJM1l04mpqPdXieYOd42rb): transfer_planner_agent_to_reviewer_agent *****
# Arguments:
# {}
# *********************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Swarm_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_planner_agent_to_reviewer_agent...
# Call ID: call_INjJM1l04mpqPdXieYOd42rb
# Input arguments: {}
# _Swarm_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_INjJM1l04mpqPdXieYOd42rb) *****
# Swarm agent --> reviewer_agent
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (20b07c95-1dfe-49ce-9a9a-3395e9c3a484): Maximum rounds (20) reached
# Number of reviews: 0
# Reviews remaining: 2
# Final Lesson Plan:
# <title>Exploring the Solar System</title>
# <learning_objectives>Key learning objectives</learning_objectives>
# 1. Understand the basic structure of the solar system, including the Sun, planets, and other celestial bodies.
# 2. Identify the names and order of the planets in the solar system.
# 3. Learn interesting facts about each planet.
# 4. Develop an appreciation for the scale and diversity of the solar system.
#
# <script>How to introduce the topic to the kids</script>
# 1. **Introduction (10 minutes)**
#    - Begin by asking the students if they have ever looked up at the night sky and wondered what is out there.
#    - Explain that today, we're going on an exciting journey through our solar system to explore the amazing worlds that exist beyond Earth.
#
# 2. **Presentation (15 minutes)**
#    - Use a visual presentation or video to introduce the solar system, starting with the Sun and moving outward to the planets.
#    - Highlight key facts about each planet, such as size, color, distance from the Sun, and any unique features (e.g., rings of Saturn or the red surface of Mars).
#
# 3. **Activity (20 minutes)**
#    - Divide the class into groups and assign each group a planet or celestial body (e.g., moons, asteroids).
#    - Provide resource materials or internet access for students to research their assigned planet.
#    - Ask each group to create a poster with interesting facts and a drawing or representation of their assigned body.
#
# 4. **Group Presentations (15 minutes)**
#    - Have each group present their poster to the class, sharing what they've learned about their assigned planet or celestial body.
#
# 5. **Conclusion (5 minutes)**
#    - Recap the main points of the lesson, emphasizing the diversity and wonders of our solar system.
#    - Encourage students to continue exploring and learning about space.
#
# 6. **Q&A (5 minutes)**
#    - Allow time for students to ask questions or share thoughts about what they found most interesting.
#
# This lesson aims to spark curiosity and a sense of wonder about the universe among the students. Through interactive activities and group work, they will retain what they've learned about the solar system more effectively.

# %%
# GroupChat with a maximum of 5 rounds
from autogen import (
    AfterWork,
    OnCondition,
    AfterWorkOption,
    ConversableAgent,
    GroupChat,
    GroupChatManager,
    SwarmResult,
    initiate_swarm_chat,
    register_hand_off,
    LLMConfig,
)

llm_config = LLMConfig(api_type="openai", model="gpt-4o", cache_seed=None)
agent_a = ConversableAgent(name="agent_a", system_message="You are a helpful assistant.")
agent_b = ConversableAgent(name="agent_b", system_message="You are a helpful assistant.")
agent_c = ConversableAgent(name="agent_c", system_message="You are a helpful assistant.")

groupchat = GroupChat(
    agents=[agent_a, agent_b, agent_c],
    speaker_selection_method="round_robin",
    max_round=5
)
gcm = GroupChatManager(
    groupchat=groupchat,
    llm_config=llm_config
)
agent_a.initiate_chat(gcm, "first message")
# 1. agent_a with "first message" > 2. agent_b > 3. agent_c > 4. agent_a > 5. agent_b > end

# Swarm with a maximum of 5 rounds
initiate_swarm_chat(
    agents=[agent_a, agent_b, agent_c],
    messages="first message",
    initial_agent=agent_a
)
# When initial agent is set to agent_a and agents hand off to the next agent.
# 1. User with "first message" > 2. agent_a > 3. agent_b > 4. agent_c > 5. agent_a > end
# Out:
# agent_a (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_b
#
#
# >>>>>>>> USING AUTO REPLY...
# agent_b (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_c
#
#
# >>>>>>>> USING AUTO REPLY...
# agent_c (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_a
#
#
# >>>>>>>> USING AUTO REPLY...
# agent_a (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_b
#
#
# >>>>>>>> USING AUTO REPLY...
# agent_b (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (2c74fbcc-3e4b-4ac0-b028-9acda8ca6943): Maximum rounds (5) reached
# _User (to chat_manager):
#
# first message
#
# --------------------------------------------------------------------------------
#
# Next speaker: agent_a
#
#
# >>>>>>>> USING AUTO REPLY...
# agent_a (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0b67e58d-d8b9-4077-ad84-1f9b5f2a3c21): No next speaker selected
# (ChatResult(chat_id=None, chat_history=[{'content': 'first message', 'role': 'assistant'}, {'content': '', 'name': 'agent_a', 'role': 'user'}], summary='', cost={'usage_including_cached_inference': {'total_cost': 0}, 'usage_excluding_cached_inference': {'total_cost': 0}}, human_input=[]),
#  None,
#  <autogen.agentchat.conversable_agent.ConversableAgent at 0x7f96fc45fb50>)

# %%
from datetime import datetime
from typing import Annotated

from autogen import ConversableAgent, register_function, LLMConfig

# Put your key in the OPENAI_API_KEY environment variable
llm_config = LLMConfig(api_type="openai", model="gpt-4o-mini")

# 1. Our tool, returns the day of the week for a given date
def get_weekday(date_string: Annotated[str, "Format: YYYY-MM-DD"]) -> str:
    date = datetime.strptime(date_string, "%Y-%m-%d")
    return date.strftime("%A")

# 2. Agent for determining whether to run the tool
with llm_config:
    date_agent = ConversableAgent(
        name="date_agent",
        system_message="You get the day of the week for a given date.",
    )

# 3. And an agent for executing the tool
executor_agent = ConversableAgent(
    name="executor_agent",
    human_input_mode="NEVER",
)

# 4. Registers the tool with the agents, the description will be used by the LLM
# register_function(
#     get_weekday,
#     caller=date_agent,
#     executor=executor_agent,
#     description="Get the day of the week for a given date",
# )
@date_agent.register_for_llm(description="Get the day of the week for a given date")
@executor_agent.register_for_execution()
def get_weekday(date_string: Annotated[str, "Format: YYYY-MM-DD"]) -> str:
    date = datetime.strptime(date_string, '%Y-%m-%d')
    return date.strftime('%A')

# 5. Two-way chat ensures the executor agent follows the suggesting agent
chat_result = executor_agent.initiate_chat(
    recipient=date_agent,
    message="I was born on the 25th of March 1995, what day was it?",
    max_turns=2,
)

print(chat_result.chat_history[-1]["content"])
# Out:
# executor_agent (to date_agent):
#
# I was born on the 25th of March 1995, what day was it?
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# date_agent (to executor_agent):
#
# ***** Suggested tool call (call_5YD9EM9bFEzFfQnL5wpXdeyJ): get_weekday *****
# Arguments:
# {"date_string":"1995-03-25"}
# ****************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_weekday...
# Call ID: call_5YD9EM9bFEzFfQnL5wpXdeyJ
# Input arguments: {'date_string': '1995-03-25'}
# executor_agent (to date_agent):
#
# ***** Response from calling tool (call_5YD9EM9bFEzFfQnL5wpXdeyJ) *****
# Saturday
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> USING AUTO REPLY...
# date_agent (to executor_agent):
#
# You were born on a Saturday, March 25, 1995.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (5798545a-5881-4aee-b6d0-7fd9f3158e0c): Maximum turns (2) reached
# You were born on a Saturday, March 25, 1995.

# %%
import autogen

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "tags": ["gpt-4o"],
    },
)

# %%
import tempfile

from autogen.coding import LocalCommandLineCodeExecutor

temp_dir = tempfile.TemporaryDirectory()
executor = LocalCommandLineCodeExecutor(
    timeout=10,  # Timeout for each code execution in seconds.
    work_dir=temp_dir.name,  # Use the temporary directory to store the code files.
)

gpt4_config = {
    "cache_seed": False,  # change the cache_seed for different trials
    "temperature": 0,
    "config_list": config_list,
    "timeout": 120,
}

initializer = autogen.UserProxyAgent(
    name="Init",
    code_execution_config=False,
)

coder = autogen.AssistantAgent(
    name="Retrieve_Action_1",
    llm_config=gpt4_config,
    system_message="""You are the Coder. Given a topic, write code to retrieve related papers from the arXiv API, print their title, authors, abstract, and link.
You write python/shell code to solve tasks. Wrap the code in a code block that specifies the script type. The user can't modify your code. So do not suggest incomplete code which requires others to modify. Don't use a code block if it's not intended to be executed by the executor.
Don't include multiple code blocks in one response. Do not ask others to copy and paste the result. Check the execution result returned by the executor.
If the result indicates there is an error, fix the error and output the code again. Suggest the full code instead of partial code or code changes. If the error can't be fixed or if the task is not solved even after the code is executed successfully, analyze the problem, revisit your assumption, collect additional info you need, and think of a different approach to try.
""",
)
executor = autogen.UserProxyAgent(
    name="Retrieve_Action_2",
    system_message="Executor. Execute the code written by the Coder and report the result.",
    human_input_mode="NEVER",
    code_execution_config={"executor": executor},
)
scientist = autogen.AssistantAgent(
    name="Research_Action_1",
    llm_config=gpt4_config,
    system_message="""You are the Scientist. Please categorize papers after seeing their abstracts printed and create a markdown table with Domain, Title, Authors, Summary and Link""",
)

def state_transition(last_speaker, groupchat):
    messages = groupchat.messages

    if last_speaker is initializer:
        # init -> retrieve
        return coder
    elif last_speaker is coder:
        # retrieve: action 1 -> action 2
        return executor
    elif last_speaker is executor:
        if messages[-1]["content"] == "exitcode: 1":
            # retrieve --(execution failed)--> retrieve
            return coder
        else:
            # retrieve --(execution success)--> research
            return scientist
    elif last_speaker == "Scientist":
        # research -> end
        return None

groupchat = autogen.GroupChat(
    agents=[initializer, coder, executor, scientist],
    messages=[],
    max_round=20,
    speaker_selection_method=state_transition,
)
manager = autogen.GroupChatManager(groupchat=groupchat, llm_config=gpt4_config)

# %%
chat_result = initializer.initiate_chat(
    manager, message="Topic: LLM applications papers from last week. Requirement: 5 - 10 papers from different domains."
)
# Out:
# Init (to chat_manager):
#
# Topic: LLM applications papers from last week. Requirement: 5 - 10 papers from different domains.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Retrieve_Action_1
#
# Retrieve_Action_1 (to chat_manager):
#
# To retrieve papers related to "LLM applications" from the arXiv API, we can use Python to query the API and filter the results based on the publication date. Here's a script that will fetch and display the required information:
#
# ```python
# import requests
# import feedparser
# from datetime import datetime, timedelta
#
# def fetch_arxiv_papers(query, max_results=10):
#     base_url = "http://export.arxiv.org/api/query?"
#     search_query = f"search_query=all:{query}&start=0&max_results={max_results}&sortBy=submittedDate&sortOrder=descending"
#     response = requests.get(base_url + search_query)
#     return feedparser.parse(response.content)
#
# def filter_papers_by_date(entries, days=7):
#     recent_papers = []
#     current_date = datetime.now()
#     for entry in entries:
#         published_date = datetime.strptime(entry.published, "%Y-%m-%dT%H:%M:%SZ")
#         if (current_date - published_date).days <= days:
#             recent_papers.append(entry)
#     return recent_papers
#
# def display_papers(papers):
#     for paper in papers:
#         print(f"Title: {paper.title}")
#         print(f"Authors: {', '.join(author.name for author in paper.authors)}")
#         print(f"Abstract: {paper.summary}")
#         print(f"Link: {paper.link}\n")
#
# def main():
#     query = "LLM applications"
#     max_results = 20  # Fetch more to ensure we get 5-10 recent papers
#     papers = fetch_arxiv_papers(query, max_results)
#     recent_papers = filter_papers_by_date(papers.entries, days=7)
#     display_papers(recent_papers[:10])  # Display up to 10 papers
#
# if __name__ == "__main__":
#     main()
# ```
#
# This script will:
#
# 1. Query the arXiv API for papers related to "LLM applications".
# 2. Filter the results to include only those published in the last week.
# 3. Display the title, authors, abstract, and link for each paper.
#
# Make sure you have the `requests` and `feedparser` libraries installed in your Python environment to run this script.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Retrieve_Action_2
#
#
# >>>>>>>> EXECUTING CODE BLOCK (inferred language is python)...
# Retrieve_Action_2 (to chat_manager):
#
# exitcode: 0 (execution succeeded)
# Code output: Title: Sculpting Subspaces: Constrained Full Fine-Tuning in LLMs for Continual
#   Learning
# Authors: Nikhil Shivakumar Nayak, Krishnateja Killamsetty, Ligong Han, Abhishek Bhandwaldar, Prateek Chanda, Kai Xu, Hao Wang, Aldo Pareja, Oleg Silkin, Mustafa Eyceoz, Akash Srivastava
# Abstract: Continual learning in large language models (LLMs) is prone to catastrophic
# forgetting, where adapting to new tasks significantly degrades performance on
# previously learned ones. Existing methods typically rely on low-rank,
# parameter-efficient updates that limit the model's expressivity and introduce
# additional parameters per task, leading to scalability issues. To address these
# limitations, we propose a novel continual full fine-tuning approach leveraging
# adaptive singular value decomposition (SVD). Our method dynamically identifies
# task-specific low-rank parameter subspaces and constrains updates to be
# orthogonal to critical directions associated with prior tasks, thus effectively
# minimizing interference without additional parameter overhead or storing
# previous task gradients. We evaluate our approach extensively on standard
# continual learning benchmarks using both encoder-decoder (T5-Large) and
# decoder-only (LLaMA-2 7B) models, spanning diverse tasks including
# classification, generation, and reasoning. Empirically, our method achieves
# state-of-the-art results, up to 7% higher average accuracy than recent
# baselines like O-LoRA, and notably maintains the model's general linguistic
# capabilities, instruction-following accuracy, and safety throughout the
# continual learning process by reducing forgetting to near-negligible levels.
# Our adaptive SVD framework effectively balances model plasticity and knowledge
# retention, providing a practical, theoretically grounded, and computationally
# scalable solution for continual learning scenarios in large language models.
# Link: http://arxiv.org/abs/2504.07097v1
#
# Title: Computing Canonical Averages with Quantum and Classical Optimizers:
#   Thermodynamic Reweighting for QUBO Models of Physical Systems
# Authors: Francesco Slongo, Cristian Micheletti
# Abstract: We present a general method to compute canonical averages for physical models
# sampled via quantum or classical quadratic unconstrained binary optimization
# (QUBO). First, we introduce a histogram reweighting scheme applicable to
# QUBO-based sampling constrained to specific intervals of an order parameter,
# e.g., physical energy. Next, we demonstrate that the scheme can accurately
# recover the density of states, which in turn allows for calculating expectation
# values in the conjugate ensemble, e.g., at a fixed temperature. The method can
# thus be used to advance the state-of-the-art characterization of physical
# systems that admit a QUBO-based representation and that are otherwise
# intractable with real-space sampling methods. A case in point are space-filling
# melts of lattice ring polymers, recently mapped in QUBO form, for which our
# method reveals that the ring catenation probability is non-monotonic with the
# bending rigidity.
# Link: http://arxiv.org/abs/2504.07094v1
#
# Title: FlashDepth: Real-time Streaming Video Depth Estimation at 2K Resolution
# Authors: Gene Chou, Wenqi Xian, Guandao Yang, Mohamed Abdelfattah, Bharath Hariharan, Noah Snavely, Ning Yu, Paul Debevec
# Abstract: A versatile video depth estimation model should (1) be accurate and
# consistent across frames, (2) produce high-resolution depth maps, and (3)
# support real-time streaming. We propose FlashDepth, a method that satisfies all
# three requirements, performing depth estimation on a 2044x1148 streaming video
# at 24 FPS. We show that, with careful modifications to pretrained single-image
# depth models, these capabilities are enabled with relatively little data and
# training. We evaluate our approach across multiple unseen datasets against
# state-of-the-art depth models, and find that ours outperforms them in terms of
# boundary sharpness and speed by a significant margin, while maintaining
# competitive accuracy. We hope our model will enable various applications that
# require high-resolution depth, such as video editing, and online
# decision-making, such as robotics.
# Link: http://arxiv.org/abs/2504.07093v1
#
# Title: Are We Done with Object-Centric Learning?
# Authors: Alexander Rubinstein, Ameya Prabhu, Matthias Bethge, Seong Joon Oh
# Abstract: Object-centric learning (OCL) seeks to learn representations that only encode
# an object, isolated from other objects or background cues in a scene. This
# approach underpins various aims, including out-of-distribution (OOD)
# generalization, sample-efficient composition, and modeling of structured
# environments. Most research has focused on developing unsupervised mechanisms
# that separate objects into discrete slots in the representation space,
# evaluated using unsupervised object discovery. However, with recent
# sample-efficient segmentation models, we can separate objects in the pixel
# space and encode them independently. This achieves remarkable zero-shot
# performance on OOD object discovery benchmarks, is scalable to foundation
# models, and can handle a variable number of slots out-of-the-box. Hence, the
# goal of OCL methods to obtain object-centric representations has been largely
# achieved. Despite this progress, a key question remains: How does the ability
# to separate objects within a scene contribute to broader OCL objectives, such
# as OOD generalization? We address this by investigating the OOD generalization
# challenge caused by spurious background cues through the lens of OCL. We
# propose a novel, training-free probe called $\textbf{Object-Centric
# Classification with Applied Masks (OCCAM)}$, demonstrating that
# segmentation-based encoding of individual objects significantly outperforms
# slot-based OCL methods. However, challenges in real-world applications remain.
# We provide the toolbox for the OCL community to use scalable object-centric
# representations, and focus on practical applications and fundamental questions,
# such as understanding object perception in human cognition. Our code is
# available $\href{https://github.com/AlexanderRubinstein/OCCAM}{here}$.
# Link: http://arxiv.org/abs/2504.07092v1
#
# Title: OmniCaptioner: One Captioner to Rule Them All
# Authors: Yiting Lu, Jiakang Yuan, Zhen Li, Shitian Zhao, Qi Qin, Xinyue Li, Le Zhuo, Licheng Wen, Dongyang Liu, Yuewen Cao, Xiangchao Yan, Xin Li, Botian Shi, Tao Chen, Zhibo Chen, Lei Bai, Bo Zhang, Peng Gao
# Abstract: We propose OmniCaptioner, a versatile visual captioning framework for
# generating fine-grained textual descriptions across a wide variety of visual
# domains. Unlike prior methods limited to specific image types (e.g., natural
# images or geometric visuals), our framework provides a unified solution for
# captioning natural images, visual text (e.g., posters, UIs, textbooks), and
# structured visuals (e.g., documents, tables, charts). By converting low-level
# pixel information into semantically rich textual representations, our framework
# bridges the gap between visual and textual modalities. Our results highlight
# three key advantages: (i) Enhanced Visual Reasoning with LLMs, where
# long-context captions of visual modalities empower LLMs, particularly the
# DeepSeek-R1 series, to reason effectively in multimodal scenarios; (ii)
# Improved Image Generation, where detailed captions improve tasks like
# text-to-image generation and image transformation; and (iii) Efficient
# Supervised Fine-Tuning (SFT), which enables faster convergence with less data.
# We believe the versatility and adaptability of OmniCaptioner can offer a new
# perspective for bridging the gap between language and visual modalities.
# Link: http://arxiv.org/abs/2504.07089v1
#
# Title: KG-LLM-Bench: A Scalable Benchmark for Evaluating LLM Reasoning on
#   Textualized Knowledge Graphs
# Authors: Elan Markowitz, Krupa Galiya, Greg Ver Steeg, Aram Galstyan
# Abstract: Knowledge graphs have emerged as a popular method for injecting up-to-date,
# factual knowledge into large language models (LLMs). This is typically achieved
# by converting the knowledge graph into text that the LLM can process in
# context. While multiple methods of encoding knowledge graphs have been
# proposed, the impact of this textualization process on LLM performance remains
# under-explored. We introduce KG-LLM-Bench, a comprehensive and extensible
# benchmark spanning five knowledge graph understanding tasks, and evaluate how
# different encoding strategies affect performance across various base models.
# Our extensive experiments with seven language models and five textualization
# strategies provide insights for optimizing LLM performance on KG reasoning
# tasks.
# Link: http://arxiv.org/abs/2504.07087v1
#
# Title: DeduCE: Deductive Consistency as a Framework to Evaluate LLM Reasoning
# Authors: Atharva Pandey, Kshitij Dubey, Rahul Sharma, Amit Sharma
# Abstract: Despite great performance on Olympiad-level reasoning problems, frontier
# large language models can still struggle on high school math when presented
# with novel problems outside standard benchmarks. Going beyond final accuracy,
# we propose a deductive consistency metric to analyze chain-of-thought output
# from language models (LMs).Formally, deductive reasoning involves two subtasks:
# understanding a set of input premises and inferring the conclusions that follow
# from them. The proposed metric studies LMs' performance on these subtasks, with
# the goal of explaining LMs' reasoning errors on novel problems: how well do LMs
# understand input premises with increasing context lengths, and how well can
# they infer conclusions over multiple reasoning hops? Since existing benchmarks
# may be memorized, we develop a pipeline to evaluate LMs' deductive consistency
# on novel, perturbed versions of benchmark problems. On novel grade school math
# problems (GSM-8k), we find that LMs are fairly robust to increasing number of
# input premises, but suffer significant accuracy decay as the number of
# reasoning hops is increased. Interestingly, these errors are masked in the
# original benchmark as all models achieve near 100% accuracy. As we increase the
# number of solution steps using a synthetic dataset, prediction over multiple
# hops still remains the major source of error compared to understanding input
# premises. Other factors, such as shifts in language style or natural
# propagation of early errors do not explain the trends. Our analysis provides a
# new view to characterize LM reasoning -- as computations over a window of input
# premises and reasoning hops -- that can provide unified evaluation across
# problem domains.
# Link: http://arxiv.org/abs/2504.07080v1
#
# Title: The Lyman-alpha and Continuum Origins Survey II: the uneventful journey
#   of escaping Ly$α$ and ionizing radiation through the neutral ISM and CGM
#   of galaxies
# Authors: A. Saldana-Lopez, M. J. Hayes, A. Le Reste, C. Scarlata, J. Melinder, A. Henry, R. Amorin, H. Atek, O. Bait, J. Chisholm, A. E. Jaskot, I. Jung, Zhiyuan Ji, L. Komarova, F. Leclercq, G. Ostlin, A. Runnholm, T. X. Thuan, X. Xu
# Abstract: One of the current challenges in galaxy evolution studies is to establish the
# mechanisms that govern the escape of ionizing radiation from galaxies. In this
# work, we investigate the connection between Lyman Continuum (LyC) escape and
# the conditions of the Circumgalactic Medium (CGM), as probed by Ly$\alpha$
# halos (LAHs) in emission. We use Ly$\alpha$ and UV continuum imaging data from
# the Lyman alpha and Continuum Origins Survey (LaCOS), targeting 42 nearby ($z
# \simeq 0.3$), star-forming galaxies with LyC observations (escape fractions of
# $f_{\rm esc}^{\rm LyC} \simeq 0.01-0.49$). LaCOS galaxies show extended
# Ly$\alpha$ emission ubiquitously, with LyC emitters (LCEs) having more compact
# Ly$\alpha$ morphologies relative to the UV size than non-LCEs, and Ly$\alpha$
# spatial offsets that do not exceed the extent of the UV continuum. We model the
# diffuse LAHs using a combined Sersic plus exponential 2D profile, and find that
# the characteristic scale length of the Ly$\alpha$ is ten times the scale length
# of the UV, on average. We unveil a tight anti-correlation between $f_{\rm
# esc}^{\rm LyC}$ and the Ly$\alpha$ Halo Fraction (HF, or contribution of the
# halo to the total Ly$\alpha$ luminosity), that we propose as a new LyC
# indicator. Our observations also show that the HF scales positively with the
# neutral gas in the ISM, revealing a picture in which Ly$\alpha$ and LyC photons
# in LCEs emerge through clear sight-lines directly from the central starbursts
# and, in the case of Ly$\alpha$, minimizing the number of scattering
# interactions in the CGM. The properties of LAHs in LaCOS resemble those of LAHs
# at $z \geq 3$, suggesting a lack of evolution in the $f_{\rm esc}^{\rm LyC}$
# predictors that rely on the spatial properties of Ly$\alpha$, and ensuring the
# applicability of these indicators to observations of high-redshift galaxies.
# Link: http://arxiv.org/abs/2504.07074v1
#
# Title: New empirical mass-loss recipe for UV radiation line-driven winds of hot
#   stars across various metallicities
# Authors: D. Pauli, L. M. Oskinova, W. -R. Hamann, A. A. C. Sander, Jorick S. Vink, M. Bernini-Peron, J. Josiek, R. R. Lefever, H. Sana, V. Ramachandran
# Abstract: The winds of massive stars remove a significant fraction of their mass,
# strongly impacting their evolution. As a star evolves, the rate at which it
# loses mass changes. In stellar evolution codes, different mass-loss recipes are
# employed for different evolutionary stages. The choice of the recipes is
# user-dependent and the conditions for switching between them are poorly
# defined. Focusing on hot stars, we aim to produce a physically motivated,
# empirically calibrated mass-loss recipe suitable for a wide range of
# metallicities. We want to provide a ready-to-use universal recipe that
# eliminates the need for switching between recipes for hot stars during stellar
# evolution calculations. We compile a sample of hot stars with reliable stellar
# and wind parameters in the Galaxy and the Magellanic Clouds. The sample is used
# to determine the dependence of the mass-loss rate on the basic stellar
# parameters. We find that independent of evolutionary stage and temperature, the
# wind mass-loss rate is a function of the electron-scattering Eddington
# parameter ($\Gamma_e$) and metallicity (Z), being in line with expectations of
# radiation-driven wind theory. Our derived scaling relation provides an adequate
# ($\Delta$log($\dot{M}$/(M$_\odot$/yr)) = 0.43) and broadly applicable mass-loss
# recipe for hot stars. The newly derived mass-loss recipe covers nearly the
# entire parameter space of hot stars with UV radiation-driven winds and
# eliminates the need for interpolation between mass-loss formulae at different
# evolutionary stages when applied in stellar evolution models. Examples of
# stellar evolution calculations using our new recipe reveal that the predictions
# on the ionizing fluxes and final fates of massive stars, especially at low
# metallicity, differ significantly from models that use the standard mass-loss
# rates, impacting our understanding of stellar populations at low metallicity
# and in the young Universe.
# Link: http://arxiv.org/abs/2504.07073v1
#
# Title: A Survey on Personalized and Pluralistic Preference Alignment in Large
#   Language Models
# Authors: Zhouhang Xie, Junda Wu, Yiran Shen, Yu Xia, Xintong Li, Aaron Chang, Ryan Rossi, Sachin Kumar, Bodhisattwa Prasad Majumder, Jingbo Shang, Prithviraj Ammanabrolu, Julian McAuley
# Abstract: Personalized preference alignment for large language models (LLMs), the
# process of tailoring LLMs to individual users' preferences, is an emerging
# research direction spanning the area of NLP and personalization. In this
# survey, we present an analysis of works on personalized alignment and modeling
# for LLMs. We introduce a taxonomy of preference alignment techniques, including
# training time, inference time, and additionally, user-modeling based methods.
# We provide analysis and discussion on the strengths and limitations of each
# group of techniques and then cover evaluation, benchmarks, as well as open
# problems in the field.
# Link: http://arxiv.org/abs/2504.07070v1
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Research_Action_1
#
# Research_Action_1 (to chat_manager):
#
# Here is a markdown table summarizing the papers on LLM applications from different domains:
#
# | Domain                  | Title                                                                 | Authors                                                                 | Summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (6d447f56-0573-4efd-9d99-63e228deb98b): No next speaker selected
